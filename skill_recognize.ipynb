# %%
import pandas as pd
job_dataset = pd.read_csv(r"/home/dell/Desktop/Skill_code/job_descriptions.csv")
job_dataset.head()
# Out:
#              Job Id     Experience Qualifications Salary Range    location  \
# 0  1089843540111562  5 to 15 Years         M.Tech    $59K-$99K     Douglas
# 1   398454096642776  2 to 12 Years            BCA   $56K-$116K    Ashgabat
# 2   481640072963533  0 to 12 Years            PhD   $61K-$104K       Macao
# 3   688192671473044  4 to 11 Years            PhD    $65K-$91K  Porto-Novo
# 4   117057806156508  1 to 12 Years            MBA    $64K-$87K    Santiago
#
#             Country  latitude  longitude  Work Type  Company Size  ...  \
# 0       Isle of Man   54.2361    -4.5481     Intern         26801  ...
# 1      Turkmenistan   38.9697    59.5563     Intern        100340  ...
# 2  Macao SAR, China   22.1987   113.5439  Temporary         84525  ...
# 3             Benin    9.3077     2.3158  Full-Time        129896  ...
# 4             Chile  -35.6751   -71.5429     Intern         53944  ...
#
#                  Contact                     Job Title  \
# ...

# %%
total_rows = len(job_dataset)
sixth = total_rows // 120

df = job_dataset.iloc[:sixth, :]
second_sixth = job_dataset.iloc[:sixth, :]
third_sixth = job_dataset.iloc[:sixth, :]
forth_sixth = job_dataset.iloc[:sixth, :]
fifth_sixth = job_dataset.iloc[:sixth, :]
sixth_sixth = job_dataset.iloc[:sixth, :]
seventh_sixth = job_dataset.iloc[:sixth, :]
eighth_sixth = job_dataset.iloc[:sixth, :]
ninenth_sixth = job_dataset.iloc[:sixth, :]
tenth_sixth = job_dataset.iloc[:sixth, :]




# show all the rows
display(df)
# Out:
#                  Job Id     Experience Qualifications Salary Range  \
# 0      1089843540111562  5 to 15 Years         M.Tech    $59K-$99K
# 1       398454096642776  2 to 12 Years            BCA   $56K-$116K
# 2       481640072963533  0 to 12 Years            PhD   $61K-$104K
# 3       688192671473044  4 to 11 Years            PhD    $65K-$91K
# 4       117057806156508  1 to 12 Years            MBA    $64K-$87K
# ...                 ...            ...            ...          ...
# 13461  3041057884411258  0 to 11 Years         B.Tech   $63K-$101K
# 13462  1366566445940913   3 to 9 Years            PhD   $60K-$120K
# 13463  1683002720236096  3 to 14 Years            BBA   $64K-$115K
# 13464  1976904092030520  4 to 15 Years         B.Tech   $60K-$113K
# 13465  2473849471120000  0 to 12 Years            BBA   $56K-$109K
#
#                  location              Country  latitude  longitude  \
# 0                 Douglas          Isle of Man   54.2361    -4.5481
# ...

# %%
unique_skills = df['skills'].unique()
print(unique_skills)
# Out:
# ['Social media platforms (e.g., Facebook, Twitter, Instagram) Content creation and scheduling Social media analytics and insights Community engagement Paid social advertising'
#  'HTML, CSS, JavaScript Frontend frameworks (e.g., React, Angular) User experience (UX)'
#  'Quality control processes and methodologies Statistical process control (SPC) Root cause analysis and corrective action Quality management systems (e.g., ISO 9001) Compliance and regulatory knowledge'
#  'Wireless network design and architecture Wi-Fi standards and protocols RF (Radio Frequency) planning and optimization Wireless security protocols Troubleshooting wireless network issues'
#  'Event planning Conference logistics Budget management Vendor coordination Marketing and promotion Client relations'
#  'Quality assurance processes Testing methodologies (e.g., manual, automated) Bug tracking and reporting Test case development Regression testing'
# ...

# %%
import spacy
from spacy.training.example import Example

# Load a blank English model
nlp = spacy.blank("en")

# Add a new entity recognizer to the pipeline
ner = nlp.add_pipe("ner")

# Add a new label for skills
ner.add_label("SKILL")

# Prepare training data (replace this with your annotated data)
training_data = [
    ("I am proficient in Python and Java.", {"entities": [
        (20, 26, "SKILL"),
          (31, 35, "SKILL")
    ]}),
    ("HTML, CSS, JavaScript Frontend frameworks eg", {"entities": [
        (0, 4, "SKILL"),  # HTML
        (6, 9, "SKILL"),  # CSS
        (11, 21, "SKILL"),  # JavaScript
        (23, 40, "SKILL")  # Frontend frameworks
    ]}),
    ("Quality control processes and methodologies Statistical process control (SPC) Root cause analysis and corrective action Quality management systems (e.g., ISO 9001) Compliance and regulatory knowledge", {"entities": [
        (0, 21, "SKILL"),  # Quality control processes and methodologies
        (22, 55, "SKILL"),  # Statistical process control (SPC)
        (56, 83, "SKILL"),  # Root cause analysis and corrective action
        (84, 123, "SKILL"),  # Quality management systems (e.g., ISO 9001)
        (124, 155, "SKILL")  # Compliance and regulatory knowledge
    ]}),
    ("Social media platforms (e.g., Facebook, Twitter, Instagram) Content creation and scheduling Social media analytics and insights Community engagement Paid social advertising", {"entities": [
        (0, 25, "SKILL"),  # Social media platforms (e.g., Facebook, Twitter, Instagram)
        (26, 59, "SKILL"),  # Content creation and scheduling
        (60, 96, "SKILL"),  # Social media analytics and insights
        (97, 118, "SKILL"),  # Community engagement
        (119, 144, "SKILL")  # Paid social advertising
    ]}),
    ("Wireless network design and architecture Wi-Fi standards and protocols RF (Radio Frequency) planning and optimization Wireless security protocols Troubleshooting wireless network issues", {"entities": [
        (0, 32, "SKILL"),  # Wireless network design and architecture
        (33, 61, "SKILL"),  # Wi-Fi standards and protocols
        (62, 98, "SKILL"),  # RF (Radio Frequency) planning and optimization
        (99, 126, "SKILL"),  # Wireless security protocols
        (127, 162, "SKILL")  # Troubleshooting wireless network issues
    ]}),
    ("Event planning Conference logistics Budget management Vendor coordination Marketing and promotion Client relations", {"entities": [
        (0, 13, "SKILL"),  # Event planning
        (14, 32, "SKILL"),  # Conference logistics
        (33, 49, "SKILL"),  # Budget management
        (50, 67, "SKILL"),  # Vendor coordination
        (68, 90, "SKILL"),  # Marketing and promotion
        (91, 105, "SKILL"),  # Client relations
    ]}),
    ("Quality assurance processes Testing methodologies Bug tracking and reporting Test case development Regression testing", {"entities": [
        (0, 22, "SKILL"),  # Quality assurance processes
        (23, 44, "SKILL"),  # Testing methodologies
        (45, 69, "SKILL"),  # Bug tracking and reporting
        (70, 93, "SKILL"),  # Test case development
        (94, 111, "SKILL"),  # Regression testing
    ]}),
    ("Teaching pedagogy Classroom management Curriculum development Student assessment Differentiated instruction", {"entities": [
        (0, 18, "SKILL"),  # Teaching pedagogy
        (19, 39, "SKILL"),  # Classroom management
        (40, 62, "SKILL"),  # Curriculum development
        (63, 79, "SKILL"),  # Student assessment
        (80, 102, "SKILL"),  # Differentiated instruction
    ]}),
    ("UI design principles and best practices Graphic design tools Typography and color theory Visual design and layout Responsive design", {"entities": [
        (0, 22, "SKILL"),  # UI design principles and best practices
        (23, 58, "SKILL"),  # Graphic design tools
        (59, 83, "SKILL"),  # Typography and color theory
        (84, 110, "SKILL"),  # Visual design and layout
        (111, 128, "SKILL"),  # Responsive design
    ]}),
    ("Interaction design principles User behavior and psychology Wireframing and prototyping tools Animation and micro-interaction design Collaborative design processes", {"entities": [
        (0, 28, "SKILL"),  # Interaction design principles
        (29, 59, "SKILL"),  # User behavior and psychology
        (60, 94, "SKILL"),  # Wireframing and prototyping tools
        (95, 132, "SKILL"),  # Animation and micro-interaction design
        (133, 163, "SKILL"),  # Collaborative design processes
    ]}),
    ("Wedding planning Vendor coordination Event management", {"entities": [
        (0, 15, "SKILL"),  # Wedding planning
        (16, 33, "SKILL"),  # Vendor coordination
        (34, 49, "SKILL"),  # Event management
    ]}),
    ("Performance testing Load testing Stress testing Test scenarios Performance monitoring Benchmarking Performance analysis", {"entities": [
        (0, 18, "SKILL"),  # Performance testing
        (19, 31, "SKILL"),  # Load testing
        (32, 45, "SKILL"),  # Stress testing
        (46, 58, "SKILL"),  # Test scenarios
        (59, 81, "SKILL"),  # Performance monitoring
        (82, 94, "SKILL"),  # Benchmarking
        (95, 115, "SKILL"),  # Performance analysis
    ]}),
    ("Family law Divorce proceedings Child custody Mediation Legal counseling Court representation", {"entities": [
        (0, 10, "SKILL"),  # Family law
        (11, 28, "SKILL"),  # Divorce proceedings
        (29, 41, "SKILL"),  # Child custody
        (42, 51, "SKILL"),  # Mediation
        (52, 68, "SKILL"),  # Legal counseling
        (69, 87, "SKILL"),  # Court representation
    ]}),
    ("Mechanical engineering CAD software Finite element analysis Product development Prototyping", {"entities": [
        (0, 21, "SKILL"),  # Mechanical engineering
        (22, 39, "SKILL"),  # CAD software
        (40, 63, "SKILL"),  # Finite element analysis
        (64, 83, "SKILL"),  # Product development
        (84, 95, "SKILL"),  # Prototyping
    ]}),
    ("Network security protocols Intrusion detection and prevention Security incident response Firewall administration Vulnerability assessment Security policies and procedures Log analysis Ethical hacking Problem-solving Communication skills Attention to detail", {"entities": [
        (0, 26, "SKILL"),  # Network security protocols
        (27, 58, "SKILL"),  # Intrusion detection and prevention
        (59, 86, "SKILL"),  # Security incident response
        (87, 112, "SKILL"),  # Firewall administration
        (113, 137, "SKILL"),  # Vulnerability assessment
        (138, 176, "SKILL"),  # Security policies and procedures
        (177, 189, "SKILL"),  # Log analysis
        (190, 203, "SKILL"),  # Ethical hacking
        (204, 220, "SKILL"),  # Problem-solving
        (221, 242, "SKILL"),  # Communication skills
        (243, 259, "SKILL"),  # Attention to detail
    ]}),
    ("Account management Sales strategy Negotiation and closing skills", {"entities": [
        (0, 16, "SKILL"),  # Account management
        (17, 31, "SKILL"),  # Sales strategy
        (32, 60, "SKILL"),  # Negotiation and closing skills
    ]}),
    ("Product branding and marketing Product lifecycle management Cross-functional team collaboration Product launch planning Market segmentation and targeting", {"entities": [
        (0, 27, "SKILL"),  # Product branding and marketing
        (28, 57, "SKILL"),  # Product lifecycle management
        (58, 94, "SKILL"),  # Cross-functional team collaboration
        (95, 120, "SKILL"),  # Product launch planning
        (121, 150, "SKILL"),  # Market segmentation and targeting
    ]}),
    ("Content creation (e.g., writing, editing, graphic design, video production) Content marketing Social media management SEO optimization Creative storytelling Audience engagement Analytics and reporting Adaptability Communication skills Creativity", {"entities": [
        (0, 16, "SKILL"),  # Content creation
        (38, 44, "SKILL"),  # writing
        (46, 53, "SKILL"),  # editing
        (55, 68, "SKILL"),  # graphic design
        (70, 83, "SKILL"),  # video production
        (85, 101, "SKILL"),  # Content marketing
        (103, 122, "SKILL"),  # Social media management
        (124, 139, "SKILL"),  # SEO optimization
        (141, 161, "SKILL"),  # Creative storytelling
        (163, 185, "SKILL"),  # Audience engagement
        (187, 208, "SKILL"),  # Analytics and reporting
        (210, 222, "SKILL"),  # Adaptability
        (224, 244, "SKILL"),  # Communication skills
        (246, 256, "SKILL"),  # Creativity
    ]}),
    ("Email deliverability best practices Spam filter testing List hygiene Blacklist monitoring Email authentication Deliverability metrics analysis Troubleshooting deliverability issues Communication skills Data analysis Attention to detail", {"entities": [
        (0, 29, "SKILL"),  # Email deliverability best practices
        (31, 49, "SKILL"),  # Spam filter testing
        (51, 63, "SKILL"),  # List hygiene
        (65, 85, "SKILL"),  # Blacklist monitoring
        (87, 125, "SKILL"),  # Email authentication
        (127, 152, "SKILL"),  # Deliverability metrics analysis
        (154, 189, "SKILL"),  # Troubleshooting deliverability issues
        (191, 212, "SKILL"),  # Communication skills
        (214, 226, "SKILL"),  # Data analysis
        (228, 244, "SKILL"),  # Attention to detail
    ]}),
    ("Human resources Recruitment Employee onboarding HRIS Record keeping Communication skills", {"entities": [
        (0, 15, "SKILL"),  # Human resources
        (17, 28, "SKILL"),  # Recruitment
        (30, 48, "SKILL"),  # Employee onboarding
        (50, 79, "SKILL"),  # HRIS (HR Information Systems)
        (81, 95, "SKILL"),  # Record keeping
        (97, 115, "SKILL"),  # Communication skills
    ]}),
    ("Legal administrative tasks Document management Calendar and docketing Transcription File organization Communication with clients and courts Knowledge of legal terminology Attention to detail Multitasking Computer skills", {"entities": [
        (0, 25, "SKILL"),  # Legal administrative tasks
        (27, 47, "SKILL"),  # Document management
        (49, 69, "SKILL"),  # Calendar and docketing
        (71, 83, "SKILL"),  # Transcription
        (85, 101, "SKILL"),  # File organization
        (103, 143, "SKILL"),  # Communication with clients and courts
        (145, 168, "SKILL"),  # Knowledge of legal terminology
        (170, 188, "SKILL"),  # Attention to detail
        (190, 202, "SKILL"),  # Multitasking
        (204, 219, "SKILL"),  # Computer skills
    ]}),
    ("Family medicine Health assessment Pediatric care Chronic disease management Patient education", {"entities": [
        (0, 14, "SKILL"),  # Family medicine
        (16, 32, "SKILL"),  # Health assessment
        (34, 48, "SKILL"),  # Pediatric care
        (50, 74, "SKILL"),  # Chronic disease management
        (76, 92, "SKILL"),  # Patient education
    ]}),
    ("Account management Client relations Marketing strategies Campaign optimization Data analysis Communication skills", {"entities": [
        (0, 17, "SKILL"),  # Account management
        (19, 34, "SKILL"),  # Client relations
        (36, 56, "SKILL"),  # Marketing strategies
        (58, 78, "SKILL"),  # Campaign optimization
        (80, 91, "SKILL"),  # Data analysis
        (93, 113, "SKILL"),  # Communication skills
    ]}),
    ("Proficiency in one or more backend programming languages (e.g., Java, Python, Node.js, Ruby) API development Database management (SQL or NoSQL) Server management and deployment Security best practices Knowledge of web frameworks (e.g., Express, Django)", {"entities": [
        (0, 59, "SKILL"),  # Proficiency in one or more backend programming languages
        (61, 74, "SKILL"),  # API development
        (76, 112, "SKILL"),  # Database management
        (114, 146, "SKILL"),  # Server management and deployment
        (148, 178, "SKILL"),  # Security best practices
        (180, 219, "SKILL"),  # Knowledge of web frameworks
    ]}),
    ("Supply chain logistics Inventory management Communication skills Problem-solving Vendor coordination", {"entities": [
        (0, 21, "SKILL"),  # Supply chain logistics
        (23, 40, "SKILL"),  # Inventory management
        (42, 61, "SKILL"),  # Communication skills
        (63, 78, "SKILL"),  # Problem-solving
        (80, 97, "SKILL"),  # Vendor coordination
    ]}),
    ("Sales training Sales coaching Training program development Sales techniques Product knowledge Presentation skills", {"entities": [
        (0, 13, "SKILL"),  # Sales training
        (15, 28, "SKILL"),  # Sales coaching
        (30, 57, "SKILL"),  # Training program development
        (59, 73, "SKILL"),  # Sales techniques
        (75, 89, "SKILL"),  # Product knowledge
        (91, 109, "SKILL"),  # Presentation skills
    ]}),
    ("Treasury management Cash flow analysis Risk management Financial forecasting Banking relations", {"entities": [
        (0, 18, "SKILL"),  # Treasury management
        (20, 35, "SKILL"),  # Cash flow analysis
        (37, 51, "SKILL"),  # Risk management
        (53, 72, "SKILL"),  # Financial forecasting
        (74, 89, "SKILL"),  # Banking relations
    ]}),
    ("Business tax law knowledge Corporate tax planning Tax compliance for businesses Tax credits and incentives Tax strategy development Financial analysis IRS regulations Client relationship management Communication skills Tax software proficiency", {"entities": [
        (0, 24, "SKILL"),  # Business tax law knowledge
        (26, 48, "SKILL"),  # Corporate tax planning
        (50, 85, "SKILL"),  # Tax compliance for businesses
        (87, 114, "SKILL"),  # Tax credits and incentives
        (116, 144, "SKILL"),  # Tax strategy development
        (146, 163, "SKILL"),  # Financial analysis
        (165, 179, "SKILL"),  # IRS regulations
        (181, 212, "SKILL"),  # Client relationship management
        (214, 234, "SKILL"),  # Communication skills
        (236, 258, "SKILL"),  # Tax software proficiency
    ]}),
    ("Training and development Performance management Learning programs Employee engagement Coaching and mentoring", {"entities": [
        (0, 23, "SKILL"),  # Training and development
        (25, 45, "SKILL"),  # Performance management
        (47, 62, "SKILL"),  # Learning programs
        (64, 83, "SKILL"),  # Employee engagement
        (85, 107, "SKILL"),  # Coaching and mentoring
    ]}),
]

# Convert training data to Example objects
examples = []
for text, annotations in training_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# Train the model
nlp.begin_training()
for _ in range(10):  # Adjust the number of iterations as needed
    for example in examples:
        nlp.update([example], drop=0.5)  # Adjust dropout rate as needed

# Save the trained model
nlp.to_disk("custom_ner_model")
# Out:
# /home/dell/.local/lib/python3.8/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "I am proficient in Python and Java." with entities "[(20, 26, 'SKILL'), (31, 35, 'SKILL')]". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# /home/dell/.local/lib/python3.8/site-packages/spacy/training/iob_utils.py:149: UserWarning: [W030] Some entities could not be aligned in the text "HTML, CSS, JavaScript Frontend frameworks eg" with entities "[(0, 4, 'SKILL'), (6, 9, 'SKILL'), (11, 21, 'SKILL...". Use `spacy.training.offsets_to_biluo_tags(nlp.make_doc(text), entities)` to check the alignment. Misaligned entities ('-') will be ignored during training.
#   warnings.warn(
# ...

# %%
import spacy

# Load the trained model
nlp = spacy.load("custom_ner_model")

# Sample text to test the model
text = 'am good at HTML and i did Treasury management'

# Process the text
doc = nlp(text)

# Access named entities
skills = [ent.text for ent in doc.ents if ent.label_ == "SKILL"]

# Print identified skills
print("Identified Skills:")
for skill in skills:
    print("-", skill)
# Out:
# Identified Skills:
# - HTML and
# - Treasury management
