# %%
import pandas as pd                 
working = pd.read_csv('dataset_token.csv')
display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# 0                douglas          isle of man     ['intern']         26801
# 1               ashgabat         turkmenistan     ['intern']        100340
# 2                  macao      macao sar china  ['temporary']         84525
# 3              portonovo                benin   ['fulltime']        129896
# 4               santiago                chile     ['intern']         53944
# ...                  ...                  ...            ...           ...
# 107359  city of victoria  hong kong sar china   ['parttime']         65917
# 107360            ottawa               canada     ['intern']         75174
# 107361         islamabad             pakistan     ['intern']        120357
# 107362        montevideo              uruguay   ['fulltime']         84553
# 107363         ngerulmud                palau  ['temporary']         13014
#
#        Job Posting Date  Preference  ...                         Job Title  \
# 0            2022-04-24  ['female']  ...  ['digital marketing specialist']
# 1            2022-12-19  ['female']  ...                 ['web developer']
# 2            2022-09-14    ['male']  ...            ['operations manager']
# 3            2023-02-25  ['female']  ...              ['network engineer']
# 4            2022-10-11  ['female']  ...                 ['event manager']
# ...                 ...         ...  ...                               ...
# 107359       2021-11-02  ['female']  ...             ['chemical engineer']
# 107360       2023-07-01    ['both']  ...                 ['uxui designer']
# 107361       2023-05-18  ['female']  ...              ['account director']
# 107362       2023-04-18    ['both']  ...            ['nurse practitioner']
# 107363       2022-07-07  ['female']  ...                    ['qa analyst']
#
#                                             Role      Job Portal  \
# 0                       ['social media manager']        snagajob
# 1                     ['frontend web developer']        idealist
# 2                    ['quality control manager']    jobs2careers
# 3                  ['wireless network engineer']        flexjobs
# 4                         ['conference manager']    jobs2careers
# ...                                          ...             ...
# 107359  ['research and development rd engineer']          indeed
# 107360               ['user interface designer']          indeed
# 107361                    ['account strategist']        snagajob
# 107362         ['acute care nurse practitioner']        flexjobs
# 107363              ['automation test engineer']  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                      Company  \
# 0                      ['icahn enterprises']
# 1           ['pnc financial services group']
# 2        ['united services automobile assn']
# 3                                   ['hess']
# 4                           ['cairn energy']
# ...                                      ...
# 107359       ['the goldman sachs group inc']
# 107360  ['thrivent financial for lutherans']
# 107361                      ['downer group']
# 107362                ['oreilly automotive']
# 107363               ['world fuel services']
#
#                                           Company Profile  \
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
#                                          tokenized_skills
# 0       ['social media', 'eg facebook', 'twitter insta...
# 1       ['html', 'css', 'javascript', 'frontend framew...
# 2       ['quality control', 'processes', 'and methodol...
# 3       ['architecture wifi standards', 'rf', 'radio',...
# 4       ['event planning', 'conference', 'logistics', ...
# ...                                                   ...
# 107359  ['processes', 'product', 'experimentation', 'd...
# 107360  ['ui design', 'principles', 'best', 'practices...
# 107361  ['account management', 'client', 'relations', ...
# 107362  ['acute care', 'nursing', 'emergency', 'critic...
# 107363  ['test automation', 'test', 'framework develop...
#
# [107364 rows x 21 columns]

# %%
working.drop(columns=['tokenized_skills'], inplace=True)
display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# 0                douglas          isle of man     ['intern']         26801
# 1               ashgabat         turkmenistan     ['intern']        100340
# 2                  macao      macao sar china  ['temporary']         84525
# 3              portonovo                benin   ['fulltime']        129896
# 4               santiago                chile     ['intern']         53944
# ...                  ...                  ...            ...           ...
# 107359  city of victoria  hong kong sar china   ['parttime']         65917
# 107360            ottawa               canada     ['intern']         75174
# 107361         islamabad             pakistan     ['intern']        120357
# 107362        montevideo              uruguay   ['fulltime']         84553
# 107363         ngerulmud                palau  ['temporary']         13014
#
#        Job Posting Date  Preference      Contact Person  \
# 0            2022-04-24  ['female']  brandon cunningham
# 1            2022-12-19  ['female']    francisco larsen
# 2            2022-09-14    ['male']         gary gibson
# 3            2023-02-25  ['female']          joy lucero
# 4            2022-10-11  ['female']       julie johnson
# ...                 ...         ...                 ...
# 107359       2021-11-02  ['female']        steven meyer
# 107360       2023-07-01    ['both']      daniel lambert
# 107361       2023-05-18  ['female']      gregory garcia
# 107362       2023-04-18    ['both']       matthew bruce
# 107363       2022-07-07  ['female']    kenneth gonzales
#
#                                Job Title  \
# 0       ['digital marketing specialist']
# 1                      ['web developer']
# 2                 ['operations manager']
# 3                   ['network engineer']
# 4                      ['event manager']
# ...                                  ...
# 107359             ['chemical engineer']
# 107360                 ['uxui designer']
# 107361              ['account director']
# 107362            ['nurse practitioner']
# 107363                    ['qa analyst']
#
#                                             Role      Job Portal  \
# 0                       ['social media manager']        snagajob
# 1                     ['frontend web developer']        idealist
# 2                    ['quality control manager']    jobs2careers
# 3                  ['wireless network engineer']        flexjobs
# 4                         ['conference manager']    jobs2careers
# ...                                          ...             ...
# 107359  ['research and development rd engineer']          indeed
# 107360               ['user interface designer']          indeed
# 107361                    ['account strategist']        snagajob
# 107362         ['acute care nurse practitioner']        flexjobs
# 107363              ['automation test engineer']  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                      Company  \
# 0                      ['icahn enterprises']
# 1           ['pnc financial services group']
# 2        ['united services automobile assn']
# 3                                   ['hess']
# 4                           ['cairn energy']
# ...                                      ...
# 107359       ['the goldman sachs group inc']
# 107360  ['thrivent financial for lutherans']
# 107361                      ['downer group']
# 107362                ['oreilly automotive']
# 107363               ['world fuel services']
#
#                                           Company Profile
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
# [107364 rows x 20 columns]

# %%
# Out:
# [nltk_data] Downloading package stopwords to /home/dell/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# 0                douglas          isle of man     ['intern']         26801
# 1               ashgabat         turkmenistan     ['intern']        100340
# 2                  macao      macao sar china  ['temporary']         84525
# 3              portonovo                benin   ['fulltime']        129896
# 4               santiago                chile     ['intern']         53944
# ...                  ...                  ...            ...           ...
# 107359  city of victoria  hong kong sar china   ['parttime']         65917
# 107360            ottawa               canada     ['intern']         75174
# 107361         islamabad             pakistan     ['intern']        120357
# 107362        montevideo              uruguay   ['fulltime']         84553
# 107363         ngerulmud                palau  ['temporary']         13014
#
#        Job Posting Date  Preference      Contact Person  \
# 0            2022-04-24  ['female']  brandon cunningham
# 1            2022-12-19  ['female']    francisco larsen
# 2            2022-09-14    ['male']         gary gibson
# 3            2023-02-25  ['female']          joy lucero
# 4            2022-10-11  ['female']       julie johnson
# ...                 ...         ...                 ...
# 107359       2021-11-02  ['female']        steven meyer
# 107360       2023-07-01    ['both']      daniel lambert
# 107361       2023-05-18  ['female']      gregory garcia
# 107362       2023-04-18    ['both']       matthew bruce
# 107363       2022-07-07  ['female']    kenneth gonzales
#
#                                Job Title  \
# 0       ['digital marketing specialist']
# 1                      ['web developer']
# 2                 ['operations manager']
# 3                   ['network engineer']
# 4                      ['event manager']
# ...                                  ...
# 107359             ['chemical engineer']
# 107360                 ['uxui designer']
# 107361              ['account director']
# 107362            ['nurse practitioner']
# 107363                    ['qa analyst']
#
#                                             Role      Job Portal  \
# 0                       ['social media manager']        snagajob
# 1                     ['frontend web developer']        idealist
# 2                    ['quality control manager']    jobs2careers
# 3                  ['wireless network engineer']        flexjobs
# 4                         ['conference manager']    jobs2careers
# ...                                          ...             ...
# 107359  ['research and development rd engineer']          indeed
# 107360               ['user interface designer']          indeed
# 107361                    ['account strategist']        snagajob
# 107362         ['acute care nurse practitioner']        flexjobs
# 107363              ['automation test engineer']  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                      Company  \
# 0                      ['icahn enterprises']
# 1           ['pnc financial services group']
# 2        ['united services automobile assn']
# 3                                   ['hess']
# 4                           ['cairn energy']
# ...                                      ...
# 107359       ['the goldman sachs group inc']
# 107360  ['thrivent financial for lutherans']
# 107361                      ['downer group']
# 107362                ['oreilly automotive']
# 107363               ['world fuel services']
#
#                                           Company Profile
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
# [107364 rows x 20 columns]

# %%
unique_skills = working['skills'].unique()
print(unique_skills)
# Out:
# ['social media platforms eg facebook twitter instagram content creation scheduling social media analytics insights community engagement paid social advertising'
#  'html css javascript frontend frameworks eg react angular user experience ux'
#  'quality control processes methodologies statistical process control spc root cause analysis corrective action quality management systems eg iso 9001 compliance regulatory knowledge'
#  'wireless network design architecture wifi standards protocols rf radio frequency planning optimization wireless security protocols troubleshooting wireless network issues'
#  'event planning conference logistics budget management vendor coordination marketing promotion client relations'
#  'quality assurance processes testing methodologies eg manual automated bug tracking reporting test case development regression testing'
#  'teaching pedagogy classroom management curriculum development student assessment differentiated instruction'
#  'ui design principles best practices graphic design tools eg adobe photoshop illustrator typography color theory visual design layout responsive design'
#  'interaction design principles user behavior psychology wireframing prototyping tools animation microinteraction design collaborative design processes'
#  'wedding planning vendor coordination event management'
#  'performance testing load testing stress testing test scenarios performance monitoring benchmarking performance analysis'
#  'family law divorce proceedings child custody mediation legal counseling court representation'
#  'mechanical engineering cad software eg solidworks autocad finite element analysis product development prototyping'
#  'network security protocols intrusion detection prevention security incident response firewall administration vulnerability assessment security policies procedures log analysis ethical hacking problemsolving communication skills attention detail'
#  'account management sales strategy negotiation closing skills'
#  'product branding marketing product lifecycle management crossfunctional team collaboration product launch planning market segmentation targeting'
#  'school social work principles student assessment intervention special education laws individualized education plans ieps crisis management collaboration educators family engagement advocacy empathy communication documentation cultural competence licensing certification'
#  'content creation eg writing editing graphic design video production content marketing social media management seo optimization creative storytelling audience engagement analytics reporting adaptability communication skills creativity'
#  'email deliverability best practices spam filter testing list hygiene blacklist monitoring email authentication eg spf dkim deliverability metrics analysis troubleshooting deliverability issues communication skills data analysis attention detail'
#  'human resources recruitment employee onboarding hris hr information systems record keeping communication skills'
#  'legal administrative tasks document management calendar docketing transcription file organization communication clients courts knowledge legal terminology attention detail multitasking computer skills eg ms office'
#  'family medicine health assessment pediatric care chronic disease management patient education'
#  'account management client relations marketing strategies campaign optimization data analysis communication skills'
#  'proficiency one backend programming languages eg java python nodejs ruby api development database management sql nosql server management deployment security best practices knowledge web frameworks eg express django'
#  'supply chain logistics inventory management communication skills problemsolving vendor coordination'
#  'b2b sales businesstobusiness sales strategies lead generation sales negotiations client relationship building market research'
#  'structural engineering principles structural analysis design software eg autocad sap2000 building codes standards project management structural integrity assessment'
#  'soc operations security incident response threat detection log analysis security tools eg idsips security alerts triage'
#  'frontend web development html css javascript responsive design web performance optimization crossbrowser compatibility'
#  'tax planning strategies tax law knowledge financial analysis retirement planning estate planning client relationship management tax optimization communication skills attention detail tax software proficiency regulatory compliance'
#  'event planning vendor coordination budget management marketing promotion logistics'
#  'clinical psychology counseling skills assessment tools diagnostic skills empathy listening skills'
#  'electrical engineering circuit design electronics autocad proficiency problemsolving'
#  'lighting design architectural lighting lighting software proficiency creative lighting concepts technical knowledge'
#  'data analysis visualization tools eg tableau power bi sql database querying business intelligence concepts data modeling reporting strong analytical problemsolving skills datadriven decisionmaking'
#  'writing skills content creation seo knowledge research skills grammar proofreading'
#  'tax law knowledge individual tax planning tax return preparation tax deductions credits tax compliance irs regulations client relationship management communication skills attention detail tax software proficiency'
#  'test automation tools eg selenium appium scripting languages eg python java test framework development continuous integration tools test data management'
#  'sales strategies tactics account management relationship building sales forecasting industry product knowledge'
#  'technical troubleshooting hardware software support customer service problemsolving communication'
#  'database design development sql database querying data modeling programming languages eg java python data security privacy regulations knowledge'
#  'social science research methods qualitative quantitative data analysis survey design implementation ethnographic research interviewing skills research ethics statistical software eg stata nvivo report writing communication skills critical thinking empathy'
#  'records management data entry retrieval attention detail'
#  'nursing care patient assessment medical knowledge'
#  'international tax law knowledge transfer pricing crossborder tax planning tax treaties agreements foreign tax credits international tax compliance transfer pricing documentation multinational tax strategies client relationship management communication skills tax software proficiency'
#  'risk assessment data analysis financial modeling risk management tools regulatory compliance knowledge'
#  'speech pathology articulation therapy language disorders speech assessment therapy planning communication skills'
#  'sales strategy development territory management sales team leadership'
#  'counseling techniques psychotherapy mental health assessment treatment planning crisis intervention ethical standards empathy active listening cultural competence documentation communication skills selfcare licensing certification'
#  'urban design planning zoning regulations gis mapping tools'
#  'account management client relationship sales strategy business development negotiation skills'
#  'user research methods usability testing data analysis interpretation'
#  'financial analysis data analysis financial modeling'
#  'desktop hardware software troubleshooting operating system expertise eg windows macos remote desktop support hardware software upgrades customer service skills'
#  'art history knowledge art curation exhibition planning collections management art market trends cultural awareness'
#  'mobile app development languages eg java swift kotlin crossplatform development eg react native flutter mobile app design principles apis web services integration debugging troubleshooting'
#  'agile methodologies scrum kanban team collaboration agile tools eg jira'
#  'quality assurance quality control process improvement audit procedures compliance standards root cause analysis'
#  'procurement processes vendor assessment contract negotiation purchase order management spend analysis market research supplier relationship management data analysis problemsolving attention detail communication skills financial acumen'
#  'family counseling marriage family therapy conflict resolution skills'
#  'supply chain analysis data analytics inventory management transportation planning problemsolving'
#  'data architecture design database management systems data modeling'
#  'document management recordkeeping attention detail data entry organizational skills'
#  'financial reporting accounting software eg quickbooks auditing gaap knowledge'
#  'sales prospecting lead generation sales presentation communication crm software eg salesforce sales negotiation closing techniques product knowledge relationship building'
#  'inventory control demand forecasting supply chain management data analysis warehouse management'
#  'test automation test framework development continuous integration scripting languages eg python test reporting code review'
#  'sustainability consulting sustainability assessments sustainable practices green building standards environmental policies client communication'
#  'electronics design pcb layout embedded systems circuit analysis troubleshooting'
#  'systems integration integration architecture data mapping middleware technologies api integration system testing troubleshooting'
#  'brand strategy development market research analysis competitive analysis brand positioning messaging creative direction collaboration'
#  'acute care nursing emergency medicine critical care diagnostic tests treatment planning'
#  'litigation legal research courtroom representation case preparation client counseling legal writing'
#  'network security protocols technologies firewalls intrusion detection systems vulnerability assessment penetration testing security policy development enforcement incident response recovery'
#  'research methodology data analysis psychological studies writing research reports critical thinking'
#  'art education curriculum program development teacher training communication skills artistic expertise'
#  'talent sourcing interviewing onboarding recruitment strategies hr software'
#  'inventory management stock control demand forecasting inventory tracking systems supply chain coordination problemsolving skills'
#  'corporate law regulations contract drafting negotiation legal research analysis risk management excellent communication negotiation skills'
#  'sql structured query language database design query optimization data modeling database maintenance problemsolving skills'
#  'procurement strategies supplier management negotiation cost analysis supply chain management'
#  'systems analysis troubleshooting support documentation'
#  'key account management sales strategy development negotiation closing skills relationship building industry market knowledge'
#  'creative writing copywriting advertising copy content creation brand storytelling marketing campaigns proofreading editing'
#  'search engine algorithms ranking factors keyword research analysis onpage offpage seo optimization seo tools eg google analytics semrush seo content strategy'
#  'sales strategy planning account management customer relationship management solution selling sales forecasting contract negotiation sales metrics reporting'
#  'construction management budgeting contract negotiation safety regulations'
#  'instructional design elearning tools curriculum development multimedia design learning theory knowledge'
#  'content strategy content planning seo optimization content marketing analytics'
#  'training program coordination training material development learning management systems'
#  'recruitment process candidate screening applicant tracking systems communication'
#  'partnership development negotiation collaboration business development'
#  'backend development restful apis database integration java ee enterprise edition performance optimization version control eg git'
#  'sales leadership team management sales strategy planning'
#  'pediatric speech therapy speechlanguage assessment individualized treatment plans child development communication skills'
#  'big data technologies hadoop spark etc data processing analysis distributed computing'
#  'nosql databases eg mongodb cassandra data modeling data migration performance tuning scalability distributed systems'
#  'demand forecasting inventory management data analysis sales operations planning sop erp software proficiency'
#  'wedding design concepts decor selection arrangement creative flair'
#  'event planning coordination budget management vendor negotiation venue selection management timeline logistics planning marketing promotion risk management client communication creativity problemsolving attention detail'
#  'investment management financial analysis risk assessment asset allocation portfolio optimization'
#  'geriatric healthcare geriatric assessment geriatric treatment elderly patient care geriatric pharmacology'
#  'javascript programming frontend development frontend frameworks eg react angular dom manipulation ajax debugging troubleshooting'
#  'account management customer relationship management sales negotiation business development client needs analysis'
#  'procurement supplier management negotiation supply chain management inventory control vendor relations'
#  'transportation planning traffic engineering gis proficiency public transportation project management'
#  'adult speech therapy speechlanguage assessment rehabilitation techniques swallowing disorders communication skills'
#  'employee benefits administration benefits compliance hris benefits communication'
#  'interior design space planning color theory material selection cad software eg sketchup client collaboration budget management'
#  'financial analysis investment evaluation portfolio management data analysis'
#  'email marketing strategies email marketing platforms eg mailchimp hubspot audience segmentation ab testing campaign analytics copywriting htmlcss email marketing automation communication skills data analysis attention detail'
#  'sustainability practices environmental management systems green certifications'
#  'serverside programming languages eg java python database management api development'
#  'system administration server maintenance active directory backup recovery cloud computing eg aws azure troubleshooting security best practices collaboration problemsolving attention detail communication skills technical knowledge'
#  'engineering design cad software proficiency problemsolving technical knowledge communication skills'
#  'market research coordination survey design administration data analysis'
#  'customer service call center operations problemsolving skills'
#  'customer relationship management onboarding training customer feedback analysis retention strategies crossselling upselling strong communication empathy customer advocacy'
#  'environmental design principles sustainability concepts cad design software'
#  'business process analysis requirement gathering data analysis communication skills'
#  'social media analytics tools eg google analytics facebook insights data analysis reporting social media roi measurement competitive analysis trend identification'
#  'child custody law family law legal advocacy negotiation court representation legal research client counseling case preparation'
#  'machine learning algorithms libraries eg scikitlearn tensorflow pytorch statistical analysis modeling data preprocessing cleaning big data technologies eg hadoop spark data visualization strong programming skills python r'
#  'clinical nursing specialization eg critical care oncology advanced nursing skills patient education'
#  'quality control quality assurance qc testing methods compliance standards root cause analysis documentation statistical analysis'
#  'electrical engineering power system analysis renewable energy systems control systems safety regulations'
#  'network security cybersecurity intrusion detection security analysis firewall management'
#  'commercial interior design workplace ergonomics building codes regulations knowledge sustainable design principles autocad revit proficiency'
#  'addiction counseling techniques substance abuse treatment counseling ethics'
#  'cloud computing platforms aws azure etc cloud security containerization docker kubernetes'
#  'data analysis data modeling data visualization sql data tools eg tableau'
#  'nursing management patient care coordination staff supervision compliance healthcare regulations quality improvement leadership skills'
#  'veterinary medicine small animal care surgery animal diagnostics preventive medicine client communication surgical skills radiology anesthesia laboratory diagnostics compassion empathy problemsolving attention detail'
#  'chemical engineering process design chemical reactions safety protocols laboratory techniques problemsolving skills'
#  'market research methodologies data collection analysis consumer behavior analysis competitor analysis survey design analysis statistical analysis software eg spss sas data visualization trend analysis report writing communication skills attention detail'
#  'network administration system administration virtualization technologies eg vmware hyperv storage management security disaster recovery planning capacity planning monitoring troubleshooting cloud infrastructure eg aws azure vendor management'
#  'test planning strategy test case design execution defect reporting tracking test automation tools eg selenium appium regression testing'
#  'project management team leadership risk management budgeting communication skills'
#  'client relationship management customer service communication skills'
#  'serverside programming eg nodejs python database management eg sql mongodb'
#  'medical product knowledge understanding healthcare regulations relationship building healthcare professionals sales forecasting planning medical sales techniques'
#  'office administration calendar management reception duties communication skills record keeping office supplies management'
#  'legal research document drafting case management efiling legal databases eg lexisnexis client communication deposition preparation trial support ethics confidentiality attention detail communication skills legal software proficiency'
#  'architectural project management construction documents building systems design coordination client communication'
#  'performance testing methodologies load testing tools eg jmeter test script development performance profiling analysis bottleneck identification'
#  'sales leadership territory management team management sales data analysis strategic planning execution'
#  'technical troubleshooting customer service communication ticketing system usage basic knowledge problemsolving criticalthinking skills'
#  'special education strategies individualized education plans ieps behavior management techniques collaboration support staff special education laws regulations knowledge'
#  'test automation frameworks tools scripting programming languages eg python java continuous integration continuous testing cict test script development maintenance test environment setup management'
#  'surgical procedures techniques operating room protocols anesthesia management'
#  'office management administrative tasks communication organization'
#  'data quality assessment improvement data profiling validation knowledge data quality tools eg informatica talend data governance principles sql data analysis attention detail data accuracy'
#  'tax preparation tax planning tax regulations accounting tax software proficiency'
#  'equine veterinary medicine horse anatomy physiology lameness evaluation equine surgery dentistry horses emergency equine care equine reproductive health compassion empathy client communication problemsolving attention detail'
#  'investment analysis portfolio management risk assessment'
#  'brand strategy brand development creative direction brand management market research'
#  'operations management strategic planning execution budgeting financial analysis leadership team management process improvement optimization'
#  'key account management relationship building sales negotiation'
#  'web accessibility standards eg wcag assistive technologies accessibility testing tools html css accessibility aria accessible rich internet applications user experience ux accessibility usability testing individuals disabilities collaboration attention detail'
#  'research methodologies data analysis literature review synthesis statistical analysis software eg spss r research proposal development strong communication reporting skills'
#  'java programming java frameworks eg spring objectoriented design code debugging software development problemsolving skills'
#  'residential interior design space planning color theory selection furniture materials selection 3d modeling rendering'
#  'office administration management budgeting expense tracking team coordination supervision facility management vendor supplier relations'
#  'strategic hr planning employee relations talent management hr policy development leadership skills'
#  'organizational time management skills calendar appointment management communication correspondence travel coordination discretion confidentiality'
#  'sales techniques strategies relationship building crm software usage product knowledge negotiation closing skills'
#  'corporate law commercial litigation dispute resolution contract law legal strategy negotiation'
#  'exotic animal medicine exotic animal diagnostics specialized surgical skills avian medicine reptile care amphibian care exotic animal anesthesia compassion empathy client communication problemsolving attention detail'
#  'brand strategy development brand identity design brand storytelling marketing campaigns brand performance measurement creative thinking strong communication skills'
#  'sourcing strategies supplier evaluation market research cost analysis contract negotiation'
#  'employee conflict resolution hr compliance employee engagement communication skills'
#  'artistic skills teaching ability communication skills art history knowledge creativity'
#  'brand management public relations brand storytelling influencer marketing media monitoring'
#  'financial management budgeting financial analysis financial reporting risk management financial software eg excel quickbooks strategic planning'
#  'network management troubleshooting network security certifications eg ccna'
#  'environmental impact analysis data collection analysis environmental regulations reporting gis geographic information systems technical writing'
#  'financial planning investment knowledge relationship management communication skills analytical skills'
#  'financial planning investment strategy retirement planning tax knowledge'
#  'systems engineering system architecture integration testing troubleshooting technical documentation configuration management'
#  'procurement processes purchase order management vendor communication data analysis inventory control'
#  'market research methodologies data collection analysis industry knowledge'
#  'supply chain logistics management inventory control procurement supplier relationship management data analysis forecasting risk assessment mitigation'
#  'data analysis tools eg sql python data visualization tools eg tableau power bi statistical analysis data cleansing transformation data modeling communication data insights problemsolving attention detail business acumen'
#  'strategic sourcing strategies supplier evaluation selection negotiation skills vendor management cost analysis supply chain management contract management problemsolving attention detail communication skills strategic thinking'
#  'real estate transactions title searches closing processes deed preparation contract review communication real estate professionals attention detail real estate terminology technology proficiency legal software proficiency legal research skills'
#  'landscape architecture site planning plant selection environmental sustainability autocad project management'
#  'urban planning zoning regulations environmental planning gis proficiency community engagement'
#  'frontend web development htmlcss responsive design user interface ui design adobe creative suite collaboration skills'
#  'pediatric assessment evaluation occupational therapy techniques children developmental milestones sensory integration therapy pediatric psychology familycentered care individualized treatment plans communication skills pediatric healthcare knowledge'
#  'graphic design typography user interface ui design adobe creative suite proficiency branding visual identity creation'
#  'sustainable design principles energy efficiency leed certification green building materials environmental impact assessment'
#  'crisis communication planning crisis response media relations reputation management stakeholder communication'
#  'employment law knowledge compliance management auditing skills employee relations communication skills'
#  'child welfare policies regulations child protective services child development crisis intervention case management cultural competence interviewing assessment skills court procedures documentation empathy communication skills'
#  'advertising marketing knowledge client relationship management advertising campaign development budget management media planning buying'
#  'inhouse counsel legal advisory employment law intellectual property regulatory compliance dispute resolution contract review client counseling'
#  'water resources engineering hydrology hydraulics environmental impact assessment water resource modeling software watershed management'
#  'market research analysis content creation copywriting social media management seo digital marketing marketing automation tools proficiency'
#  'dental hygiene knowledge teaching instructional skills curriculum development student assessment clinical practice experience'
#  'administrative leadership office management staff supervision budgeting financial management process improvement communication skills'
#  'search engine marketing sem google ads bing ads keyword analysis ad performance analysis sem strategy development bid management'
#  'technical seo audits website crawl analysis schema markup xml sitemaps canonicalization'
#  'corporate event planning corporate branding messaging speaker entertainment booking audiovisual production team coordination crisis management budgeting financial management client communication creativity problemsolving attention detail'
#  'uiux design frontend web development wireframing prototyping user research accessibility standards responsive design collaboration skills'
#  'pediatric surgery surgical procedures children operating room protocols patient care surgical techniques pediatric anesthesia'
#  'project management communication time management organization problemsolving'
#  'quality assurance process improvement team leadership problemsolving quality control'
#  'mergers acquisitions expertise due diligence valuation techniques'
#  'industrial engineering process optimization lean manufacturing quality control data analysis workflow design'
#  'seo search engine optimization keyword research seofriendly content onpage optimization meta tags seo tools eg semrush'
#  'product positioning messaging market research analysis product launch planning competitive analysis marketing collateral creation pricing strategies crossfunctional collaboration'
#  'machine learning algorithms python programming data preprocessing deep learning model evaluation'
#  'digital marketing strategy development social media advertising email marketing google analytics seo content management systems cms proficiency'
#  'architectural design software eg autocad revit building codes regulations 3d modeling visualization sustainable design'
#  'proficiency html css javascript experience frontend frameworks like react angular vuejs responsive web design crossbrowser compatibility version control eg git frontend performance optimization'
#  'data analysis database querying reporting data visualization sql proficiency data quality assurance'
#  'content strategy seo content optimization content marketing keyword mapping analytics'
#  'live chat support online customer communication problem resolution'
#  'intellectual property law trademark patent law copyright law ip portfolio management litigation dispute resolution'
#  'wealth management strategies asset allocation estate planning tax management client relationship management'
#  'art instruction classroom management art techniques lesson planning student assessment'
#  'etl extract transform load processes data integration sql scripting languages'
#  'administrative support calendar management communication skills time management organizational skills confidentiality'
#  'technical troubleshooting customer support tools eg zendesk freshdesk communication skills problemsolving critical thinking ticket management knowledge base creation'
#  'corporate legal tasks document drafting compliance corporate governance contract management due diligence entity formation communication stakeholders attention detail technology proficiency legal software proficiency legal research skills'
#  'technical seo website audits seo tools eg screaming frog ahrefs schema markup site speed optimization xml sitemaps canonicalization'
#  'nursing care patient assessment health promotion medication administration electronic health records ehr'
#  'accounting financial reporting financial audits tax compliance accounting software eg sap oracle gaap generally accepted accounting principles'
#  'supply chain management inventory control transportation logistics vendor relations team leadership management'
#  'medical diagnosis patient care medical recordkeeping communication skills empathy compassion'
#  'social media marketing strategy development content planning creation social media advertising targeting datadriven decisionmaking social media trends platform updates'
#  'user experience ux design user interface ui design wireframing prototyping usability testing design tools like sketch figma'
#  'customer support team leadership customer satisfaction issue resolution performance metrics training development'
#  'geriatric assessment evaluation geriatricspecific occupational therapy techniques agingrelated conditions eg dementia arthritis fall prevention strategies care coordination healthcare teams assistive technology seniors patient advocacy empathy compassion communication skills'
#  'usercentered design principles uxui design tools eg sketch adobe xd wireframing prototyping usability testing user research information architecture user flows'
#  'network performance analysis network monitoring tools eg wireshark troubleshooting capacity planning data analysis network protocols'
#  'database management systems eg mysql oracle sql server data security database tuning optimization backup recovery'
#  'computeraided design cad software technical drawing blueprint interpretation drafting standards engineering principles collaboration engineers problemsolving attention detail communication skills 3d modeling applicable'
#  'user interface ui design user experience ux design web design principles prototyping wireframing frontend development languages eg html css javascript interaction design user testing responsive design usability testing collaboration attention detail'
#  'corporate law compliance mergers acquisitions corporate governance contract drafting risk management legal strategy due diligence'
#  'marketing analytics data analysis tools eg google analytics adobe analytics brand performance measurement consumer behavior analysis campaign effectiveness evaluation'
#  'manufacturing processes knowledge cadcam software proficiency lean manufacturing principles quality control assurance six sigma certification'
#  'negotiation skills vendor management supply chain knowledge contract management analytical skills'
#  'security consulting risk assessment security audits security policy development penetration testing client communication'
#  'strategic planning leadership management budgeting financial management governance compliance vendor management cybersecurity risk management project management cloud computing network infrastructure enterprise software systems'
#  'marketing analytics data analysis data visualization market research google analytics marketing automation reporting tools'
#  'data collection analysis market research tools techniques survey design analysis qualitative quantitative research methods report writing presentation skills'
#  'automation scripting eg python bash continuous integrationcontinuous deployment cicd containerization eg docker kubernetes infrastructure code eg terraform ansible cloud platforms eg aws azure gcp monitoring troubleshooting skills'
#  'legal counsel legal advice contract negotiation legal research litigation support client representation legal writing regulatory compliance'
#  'database security measures data encryption access control security compliance vulnerability assessment database auditing monitoring'
#  'print design software eg adobe indesign illustrator layout composition print production processes color theory management attention detail print industry knowledge'
#  'digital marketing strategies seo sem social media marketing email marketing campaigns content marketing web analytics eg google analytics marketing automation tools eg hubspot marketo'
#  'ediscovery tools processes document review production litigation support software eg relativity data analysis case management communication legal teams technical proficiency attention detail problemsolving legal research skills'
#  'content strategy content creation blog management content promotion seo analytics reporting'
#  'mediation conflict resolution negotiation communication skills neutrality problemsolving legal knowledge mediation techniques'
#  'accounting principles financial reporting team management budgeting financial analysis'
#  'sales management sales strategy development team leadership'
#  'help desk support ticket resolution troubleshooting customer service skills technical knowledge documentation knowledge base maintenance communication interpersonal skills'
#  'wedding planning venue selection catering menu planning floral decor design wedding etiquette'
#  'control system design plc programming automation instrumentation system integration'
#  'pediatrics pediatric care diagnosis treatment pediatric medical procedures patient care communication skills'
#  'facilities management property maintenance space planning budget management health safety compliance vendor management'
#  'pediatric rehabilitation developmental assessments child psychology knowledge'
#  'investment strategies portfolio management financial planning risk assessment regulatory compliance'
#  'digital marketing strategy social media marketing content creation seo search engine optimization ppc advertising analytics reporting'
#  'cloud systems engineering cloud infrastructure eg aws azure devops practices automation security cloud disaster recovery scalability'
#  'industrial design principles cad 3d modeling prototyping testing'
#  'network infrastructure design routing switching network protocols eg tcpip cisco juniper certifications troubleshooting diagnostics security protocols wireless networking network monitoring collaboration problemsolving attention detail'
#  'marketing automation platforms eg marketo pardot lead nurturing workflow automation crm integration analytics reporting email marketing campaign optimization marketing strategy communication skills problemsolving attention detail'
#  'network administration system server maintenance cybersecurity knowledge backup recovery project management skills'
#  'calendar management travel coordination meeting scheduling correspondence communication office organization confidentiality time management problemsolving attention detail communication skills technology proficiency eg ms office'
#  'quality assurance processes methodologies quality metrics kpis audit compliance team leadership management continuous improvement initiatives'
#  'analytical chemistry laboratory techniques instrumentation data analysis quality control sample preparation scientific software eg chemdraw'
#  'environmental compliance regulatory requirements environmental impact assessments reporting environmental regulations auditing'
#  'email marketing platforms eg mailchimp constant contact email campaign creation segmentation ab testing optimization email deliverability compliance metrics tracking analysis'
#  'social media management content creation audience engagement marketing strategy communication skills'
#  'employment law regulations employment contracts agreements workplace discrimination harassment laws legal compliance client representation advocacy'
#  'construction project management building codes regulations knowledge budgeting cost control construction scheduling contractor subcontractor coordination'
#  'supplier diversity programs diversity inclusion initiatives supplier assessment certification data collection reporting vendor outreach engagement strategic planning communication skills relationship building attention diversity inclusion principles'
#  'transportation engineering traffic analysis planning civil engineering software eg microstation autocad civil 3d roadway design public transportation knowledge'
#  'environmental assessments regulatory compliance environmental impact analysis'
#  'agile product development scrum kanban frameworks backlog management user story writing prioritization techniques collaboration development teams product vision strategy'
#  'architectural drafting autocad 2d 3d modeling blueprint reading building codes collaboration architects detailoriented'
#  'clinical nursing patient assessment care planning staff development healthcare protocols communication skills problemsolving abilities'
#  'web design concepts graphic design software eg adobe creative suite html css responsive design user interface ui principles visual communication typography color theory creativity attention detail collaboration'
#  'customer experience strategy customer journey mapping feedback analysis user research metrics kpis communication skills'
#  'frontend backend development database integration problemsolving api knowledge'
#  'network troubleshooting support network configuration technical knowledge problemsolving'
#  'avionics systems electronic warfare systems radar systems aircraft communication systems system integration testing validation'
#  'system administration network administration troubleshooting security management server maintenance backup recovery'
#  'hospitality interior design hotel restaurant design branding theme integration ffe furniture fixtures equipment selection customer experience design'
#  'project planning scheduling budget management risk assessment mitigation stakeholder communication agile waterfall methodologies'
#  'onboarding process management new employee orientation training development hr policies procedures employee engagement strategies'
#  'search engine optimization keyword research seo tools eg google analytics semrush onpage offpage optimization'
#  'budget planning financial forecasting excel proficiency data analysis'
#  'business systems analysis requirements gathering process improvement'
#  'pediatric specialization advanced pediatric care pediatric subspecialty eg pediatric cardiology pediatric oncology pediatric diagnostics pediatric treatment'
#  'marketing communication public relations content strategy crisis management media relations'
#  'addiction recovery support motivational interviewing relapse prevention strategies'
#  'mental health assessment evaluation psychotherapy techniques cognitivebehavioral therapy cbt traumainformed care crisis intervention substance abuse treatment group therapy cultural competence ethical standards boundaries active listening skills'
#  'customer service sales techniques product knowledge cash handling communication skills'
#  'knowledge hvac systems equipment mechanical engineering skills problemsolving abilities autocad proficiency hvac design installation expertise'
#  'pcb design electronics pcb layout software proficiency circuit design quality control'
#  'creative leadership art direction concept development visual design advertising marketing expertise'
#  'nursing education curriculum development clinical instruction assessment evaluation educational technology communication skills'
#  'data integration etl extract transform load big data technologies eg hadoop spark database management data warehousing'
#  'search engine marketing ppc advertising seo strategy data analysis digital marketing skills'
#  'healthcare industry knowledge health data analysis hipaa regulations emr systems'
#  'user interface ui design user experience ux design wireframing prototyping tools eg sketch figma usability testing information architecture interaction design mobile responsive design'
#  'retirement planning social security investment products tax planning estate planning'
#  'school psychology special education knowledge assessment testing individualized education plans collaboration skills'
#  'data entry accuracy speed database software eg microsoft access excel attention detail time management organization multitasking keyboarding skills data verification problemsolving communication skills computer proficiency'
#  'software quality assurance test planning test case design test execution defect tracking test automation eg selenium'
#  'nursing leadership charge nurse responsibilities team coordination'
#  'api design development restful api knowledge security protocols oauth jwt'
#  'user experience strategy user journey mapping design thinking'
#  'quality control processes quality assurance standards eg iso statistical analysis inspection techniques documenting quality issues root cause analysis communication production teams problemsolving attention detail technical knowledge'
#  'product management principles technical background agile development methodologies product roadmap planning market research analysis stakeholder communication problemsolving skills'
#  'construction management structural design autocad proficiency project management site inspection'
#  'orthopedic assessment treatment rehabilitation exercises patient education'
#  'business development sales strategy market analysis client acquisition team leadership strategic planning presentation skills'
#  'usability evaluation user interface assessment usability testing tools techniques'
#  'forensic accounting fraud detection legal knowledge investigative skills'
#  'customer service problemsolving communication skills ticketing system usage product knowledge'
#  'enterprise architecture business strategy alignment governance compliance'
#  'event planning management budgeting financial management vendor sponsor relations promotion publicity event logistics coordination skills'
#  'corporate event planning corporate branding corporate communication audiovisual equipment crisis management'
#  'media relations press releases media outreach crisis communication public relations strategies'
#  'dental public health principles community outreach education dental health program planning epidemiology knowledge public health regulations knowledge'
#  'copywriting content creation seo marketing strategies creativity'
#  'aerospace engineering cad software eg autocad aerodynamics structural analysis aircraft systems safety regulations'
#  'google ads management ppc campaign optimization keyword research ad copywriting ab testing conversion tracking'
#  'environmental regulations ecosystem analysis environmental impact assessments sustainability planning project management'
#  'community engagement moderation online communitybuilding strategies content curation creation crisis management conflict resolution analytics reporting'
#  'process optimization manufacturing processes lean six sigma methodologies data analysis statistical process control quality management root cause analysis collaboration problemsolving attention detail technical knowledge'
#  'data analysis techniques research methodologies data collection interpretation statistical analysis software eg r python data visualization tools eg tableau power bi research report writing critical thinking problemsolving communication skills attention detail'
#  'landscape design plant selection care hardscape design'
#  'periodontal therapy procedures patient care communication dental instrumentation periodontal disease management oral health education'
#  'sustainable landscape design native plant selection water conservation soil health green building practices leed certification'
#  'digital marketing strategy marketing analytics team leadership content marketing seo sem proficiency'
#  'pediatric healthcare pediatric assessment pediatric treatment patient education pediatric pharmacology'
#  'sales strategies customer relationship management sales techniques product knowledge client acquisition negotiation skills'
#  'geriatric rehabilitation fall prevention elderly patient care'
#  'technical documentation technical knowledge writing skills editing user manuals'
#  'hvac system design load calculations energy efficiency autocad similar software mechanical engineering principles collaboration architects engineers regulatory compliance problemsolving attention detail communication skills'
#  'research chemistry experimental design data interpretation chemical synthesis research protocols scientific writing problemsolving skills'
#  'legal research document drafting communication skills legal software proficiency attention detail'
#  'office administration communication skills organizational skills time management microsoft office proficiency'
#  'hr policies procedures employee relations recruitment communication skills'
#  'cybersecurity security assessments intrusion detection security tools eg siem incident response vulnerability scanning'
#  'financial planning investment strategies team leadership wealth management client advisory skills'
#  'web application development java web frameworks eg servlets jsp frontend integration user authentication security protocols code documentation'
#  'product knowledge demonstrating skills sales techniques customer engagement communication skills'
#  'bridge design civil engineering structural analysis autocad proficiency project management'
#  'sales prospecting networking facetoface sales meetings territory management consultative selling relationship building sales tracking reporting'
#  'wedding planning vendor coordination ceremony reception logistics wedding etiquette budget management timeline planning attention detail client communication creativity problemsolving emotional intelligence event design'
#  'emergency medical care triage assessment trauma management'
#  'ecommerce web design uxui design shopping cart integration payment gateway integration mobile responsiveness ecommerce platforms eg shopify'
#  'technical writing documentation user manuals technical specifications industryspecific terminology research skills'
#  'market expansion strategies market research sales planning execution'
#  'solution design technical architecture cloud computing software development knowledge'
#  'research development processes product innovation prototype development testing experimentation data analysis collaboration crossfunctional teams problemsolving attention detail technical expertise project management skills'
#  'competitive analysis market research data analysis business strategy industry knowledge'
#  'legal research discovery management case preparation trial support document review client communication efiling attention detail multitasking legal terminology technology proficiency communication skills legal software proficiency'
#  'medical knowledge clinical skills patient care assessment communication empathy'
#  'graphic design tools eg adobe creative suite web design principles user interface ui design visual communication typography creativity artistic skills'
#  'product design principles prototyping wireframing user research user testing uiux design 3d modeling applicable collaboration problemsolving creativity attention detail communication skills software proficiency eg sketch adobe xd'
#  'digital marketing strategies analytics reporting seo sem social media marketing email marketing data interpretation marketing automation tools ab testing communication skills problemsolving attention detail marketing knowledge'
#  'knowledge court procedures legal document management attention detail computer literacy organization skills'
#  'expertise specific subject area knowledge curriculum standards instructional design assessment development educational technology proficiency'
#  'brand promotion marketing knowledge communication skills sales techniques product knowledge'
#  'seo search engine optimization content strategy keyword research content optimization content planning analytics reporting'
#  'sales training sales coaching training program development sales techniques product knowledge presentation skills'
#  'treasury management cash flow analysis risk management financial forecasting banking relations'
#  'business tax law knowledge corporate tax planning tax compliance businesses tax credits incentives tax strategy development financial analysis irs regulations client relationship management communication skills tax software proficiency'
#  'training development performance management learning programs employee engagement coaching mentoring']

# %%
import spacy
from spacy.training.example import Example

# Load a blank English model
nlp = spacy.blank("en")

# Add a new entity recognizer to the pipeline
ner = nlp.add_pipe("ner")

# Add a new label for skills
ner.add_label("SKILL")

# Prepare training data (replace this with your annotated data)
training_data = [
    ("social media platforms eg facebook twitter instagram content creation scheduling social media analytics insights community engagement paid social advertising",
     {"entities": [
        (53, 83, "SKILL"),  # content creation and scheduling
        (85, 119, "SKILL"),  # social media analytics and insights
        (121, 140, "SKILL"),  # community engagement
        (142, 164, "SKILL")  # paid social advertising
    ]}),
    ("html css javascript frontend frameworks eg react angular user experience ux",
     {"entities": [
        (0, 3, "SKILL"),  # html
        (5, 7, "SKILL"),  # css
        (9, 19, "SKILL"),  # javascript
        (20, 38, "SKILL"),  # frontend frameworks
        (57, 74, "SKILL")  # user experience ux
    ]}),

    ("i am proficient in python and java", {"entities": [
        (19, 24, "SKILL"),
          (30, 33, "SKILL")
    ]}),
    
    ("quality control processes and methodologies statistical process control (spc) root cause analysis and corrective action quality management systems (e.g., iso 9001) compliance and regulatory knowledge", {"entities": [
        (0, 42, "SKILL"),  # quality control processes and methodologies
        (44, 76, "SKILL"),  # Statistical process control (SPC)
        (78, 118, "SKILL"),  # root cause analysis and corrective action
        (120, 145, "SKILL"),  # quality management systems (e.g., ISO 9001)
        (164, 198, "SKILL")  # compliance and regulatory knowledge
    ]}),
    
    ("wireless network design and architecture wi-fi standards and protocols rf (radio frequency) planning and optimization wireless security protocols troubleshooting wireless network issues", {"entities": [
        (0, 39, "SKILL"),  # wireless network design and architecture
        # (0, 22, "SKILL"),  # wireless network design
        # (28, 39, "SKILL"),  # architecture
        (41, 69, "SKILL"),  # wi-fi standards and protocols
        (71, 116, "SKILL"),  # RF (Radio Frequency) planning and optimization
        (118, 144, "SKILL"),  # wireless security protocols
        (146, 184, "SKILL")  # troubleshooting wireless network issues
    ]}),
    ("event planning conference logistics budget management vendor coordination marketing and promotion client relations", {"entities": [
        (0, 13, "SKILL"),  # event planning
        (15, 34, "SKILL"),  # conference logistics
        (36, 52, "SKILL"),  # budget management
        (54, 72, "SKILL"),  # vendor coordination
        (74, 96, "SKILL"),  # marketing and promotion
        (98, 113, "SKILL"),  # client relations
    ]}),
    ("quality assurance processes testing methodologies bug tracking and reporting test case development regression testing", {"entities": [
        (0, 26, "SKILL"),  # quality assurance processes
        (27, 48, "SKILL"),  # testing methodologies
        # (50, 61, "SKILL"),  # bug tracking
        (50, 75, "SKILL"),  # bug tracking and reporting
        (77, 97, "SKILL"),  # test case development
        (99, 116, "SKILL"),  # regression testing
    ]}),
    ("teaching pedagogy classroom management curriculum development student assessment differentiated instruction", {"entities": [
        (0, 16, "SKILL"),  # teaching pedagogy
        (18, 37, "SKILL"),  # classroom management
        (39, 60, "SKILL"),  # curriculum development
        (62, 79, "SKILL"),  # student assessment
        (81, 106, "SKILL"),  # differentiated instruction
    ]}),
    ("ui design principles and best practices graphic design tools typography and color theory visual design and layout responsive design", {"entities": [
        # (0, 8, "SKILL"),  # ui design 
        (0, 38, "SKILL"),  # ui design principles and best practices
        # (40, 53, "SKILL"),  # graphic design
        (40, 59, "SKILL"),  # graphic design tools
        # (76, 87, "SKILL"),  # color theory
        (61, 87, "SKILL"),  # typography and color theory
        # (89, 101, "SKILL"),  # visual design 
        (89, 112, "SKILL"),  # visual design and layout
        (114, 130, "SKILL"),  # responsive design
    ]}),
    ("interaction design principles user behavior and psychology wireframing and prototyping tools animation and micro-interaction design collaborative design processes", {"entities": [
        (0, 28, "SKILL"),  # interaction design principles
        (30, 57, "SKILL"),  # user behavior and psychology
        (59, 91, "SKILL"),  # wireframing and prototyping tools
        (93, 130, "SKILL"),  # animation and micro-interaction design
        (131, 161, "SKILL"),  # collaborative design processes
    ]}),
    ("wedding planning vendor coordination event management", {"entities": [
        (0, 15, "SKILL"),  # wedding planning
        (17, 35, "SKILL"),  # vendor coordination
        (37, 52, "SKILL"),  # event management
    ]}),
    ("performance testing load testing stress testing test scenarios performance monitoring benchmarking performance analysis", {"entities": [
        (0, 18, "SKILL"),  # performance testing
        (20, 31, "SKILL"),  # load testing
        (33, 46, "SKILL"),  # stress testing
        (48, 61, "SKILL"),  # test scenarios
        (63, 84, "SKILL"),  # performance monitoring
        (86, 97, "SKILL"),  # benchmarking
        (99, 118, "SKILL"),  # performance analysis
    ]}),
    ("family law divorce proceedings child custody mediation legal counseling court representation", {"entities": [
        (0, 9, "SKILL"),  # family law
        (11, 29, "SKILL"),  # divorce proceedings
        (29, 41, "SKILL"),  # child custody
        (45, 53, "SKILL"),  # mediation
        (55, 70, "SKILL"),  # legal counseling
        (72, 91, "SKILL"),  # court representation
    ]}),
    ("mechanical engineering cad software finite element analysis product development prototyping", {"entities": [
        (0, 21, "SKILL"),  # mechanical engineering
        (23, 34, "SKILL"),  # cad software
        (36, 58, "SKILL"),  # finite element analysis
        (60, 78, "SKILL"),  # product development
        (80, 90, "SKILL"),  # prototyping
    ]}),
    ("network security protocols intrusion detection and prevention security incident response firewall administration vulnerability assessment security policies and procedures log analysis ethical hacking problem-solving communication skills attention to detail", {"entities": [
        (0, 25, "SKILL"),  # network security protocols
        (27, 60, "SKILL"),  # intrusion detection and prevention
        (62, 87, "SKILL"),  # security incident response
        (89, 111, "SKILL"),  # firewall administration
        (113, 136, "SKILL"),  # vulnerability assessment
        (138, 169, "SKILL"),  # security policies and procedures
        (171, 182, "SKILL"),  # log analysis
        (184, 198, "SKILL"),  # ethical hacking
        (200, 214, "SKILL"),  # problem-solving
        (216, 235, "SKILL"),  # communication skills
        (237, 255, "SKILL"),  # attention to detail
    ]}),
    ("account management sales strategy negotiation and closing skills", {"entities": [
        (0, 17, "SKILL"),  # account management
        (17, 31, "SKILL"),  # sales strategy
        (34, 63, "SKILL"),  # negotiation and closing skills
    ]}),
    ("product branding and marketing product lifecycle management cross-functional team collaboration product launch planning market segmentation and targeting", {"entities": [
        (0, 29, "SKILL"),  # product branding and marketing
        (31, 58, "SKILL"),  # product lifecycle management
        (60, 94, "SKILL"),  # cross-functional team collaboration
        (96, 118, "SKILL"),  # product launch planning
        (120, 152, "SKILL"),  # market segmentation and targeting
    ]}),
    ("email deliverability best practices spam filter testing list hygiene blacklist monitoring email authentication deliverability metrics analysis troubleshooting deliverability issues communication skills data analysis attention to detail", {"entities": [
        (0, 19, "SKILL"),  # email deliverability best practices
        (36, 54, "SKILL"),  # spam filter testing
        (56, 67, "SKILL"),  # Lemail deliverability best practices spam filter testing list hygiene blacklist monitoring email authentication deliverability metrics analysis troubleshooting deliverability issues communication skills data analysis attention to detail
        (69, 88, "SKILL"),  # blacklist monitoring
        (90, 109, "SKILL"),  # email authentication
        (111, 141, "SKILL"),  # deliverability metrics analysis
        (143, 179, "SKILL"),  # troubleshooting deliverability issues
        (181, 200, "SKILL"),  # Communication skills
        (202, 214, "SKILL"),  # data analysis
        (216, 234, "SKILL"),  # attention to detail
    ]}),
    ("human resources recruitment employee onboarding hris record keeping communication skills", {"entities": [
        (0, 14, "SKILL"),  # human resources
        (16, 26, "SKILL"),  # recruitment
        (328, 46, "SKILL"),  # employee onboarding
        (48, 51, "SKILL"),  # hris (hr information systems)
        (53, 66, "SKILL"),  # record keeping
        (68, 87, "SKILL"),  # communication skills
    ]}),
    ("legal administrative tasks document management calendar and docketing transcription file organization communication with clients and courts knowledge of legal terminology attention to detail multitasking computer skills", {"entities": [
        (0, 25, "SKILL"),  # legal administrative tasks
        (27, 45, "SKILL"),  # document management
        (47, 64, "SKILL"),  # calendar docketing
        (66, 78, "SKILL"),  # transcription
        (80, 96, "SKILL"),  # file organization
        (98, 130, "SKILL"),  # communication with clients courts
        (132, 161, "SKILL"),  # knowledge of legal terminology
        (163, 181, "SKILL"),  # attention to detail
        (183, 194, "SKILL"),  # multitasking
        (196, 210, "SKILL"),  # computer skills
    ]}),
    ("family medicine health assessment pediatric care chronic disease management patient education", {"entities": [
        (0, 14, "SKILL"),  # family medicine
        (16, 32, "SKILL"),  # health assessment
        (34, 47, "SKILL"),  # pediatric care
        (49, 74, "SKILL"),  # chronic disease management
        (76, 92, "SKILL"),  # patient education
    ]}),
    ("account management client relations marketing strategies campaign optimization data analysis communication skills", {"entities": [
        (0, 17, "SKILL"),  # account management
        (19, 34, "SKILL"),  # client relations
        (36, 55, "SKILL"),  # marketing strategies
        (57, 77, "SKILL"),  # campaign optimization
        (79, 91, "SKILL"),  # data analysis
        (93, 112, "SKILL"),  # communication skills
    ]}),
    ("proficiency in one or more backend programming languages (e.g., java, python, node.js, ruby) api development database management (sql or nosql) server management and deployment security best practices knowledge of web frameworks (e.g., express, django)", {"entities": [
        (0, 59, "SKILL"),  # Proficiency in one or more backend programming languages
        (61, 74, "SKILL"),  # API development
        (76, 112, "SKILL"),  # Database management
        (114, 146, "SKILL"),  # Server management and deployment
        (148, 178, "SKILL"),  # Security best practices
        (180, 219, "SKILL"),  # Knowledge of web frameworks
    ]}),
    ("supply chain logistics inventory management communication skills problem-solving vendor coordination", {"entities": [
        (0, 21, "SKILL"),  # supply chain logistics
        (23, 42, "SKILL"),  # inventory management
        (44, 63, "SKILL"),  # communication skills
        (65, 79, "SKILL"),  # problem-solving
        (80, 98, "SKILL"),  # vendor coordination
    ]}),
    ("sales training sales coaching training program development sales techniques product knowledge presentation skills", {"entities": [
        (0, 13, "SKILL"),  # sales training
        (15, 28, "SKILL"),  # sales coaching
        (30, 57, "SKILL"),  # training program development
        (59, 74, "SKILL"),  # sales techniques
        (76, 92, "SKILL"),  # product knowledge
        (94, 112, "SKILL"),  # presentation skills
    ]}),
    ("treasury management cash flow analysis risk management financial forecasting banking relations", {"entities": [
        (0, 18, "SKILL"),  # treasury management
        (20, 37, "SKILL"),  # cash flow analysis
        (39, 53, "SKILL"),  # risk management
        (55, 75, "SKILL"),  # financial forecasting
        (77, 93, "SKILL"),  # banking relations
    ]}),
    ("business tax law knowledge corporate tax planning tax compliance for businesses tax credits and incentives tax strategy development financial analysis irs regulations client relationship management communication skills tax software proficiency", {"entities": [
        (0, 25, "SKILL"),  # business tax law knowledge
        (27, 48, "SKILL"),  # corporate tax planning
        (50, 78, "SKILL"),  # tax compliance for businesses
        (80, 10, "SKILL"),  # tax credits and incentives
        (107, 130, "SKILL"),  # tax strategy development
        (132, 149, "SKILL"),  # financial analysis
        (151, 165, "SKILL"),  # irs regulations
        (167, 196, "SKILL"),  # client relationship management
        (198, 217, "SKILL"),  #communication skills
        (219, 242, "SKILL"),  # tax software proficiency
    ]}),
    ("training and development performance management learning programs employee engagement coaching and mentoring", {"entities": [
        (0, 23, "SKILL"),  # training and development
        (25, 46, "SKILL"),  # performance management
        (48, 64, "SKILL"),  # learning programs
        (66, 84, "SKILL"),  # employee engagement
        (86, 107, "SKILL"),  # coaching and mentoring
    ]}),
    ("project management leadership strategic planning team coordination budget management risk assessment", {"entities": [
        (0, 17, "SKILL"),  # project management
        (19, 28, "SKILL"),  # leadership
        (30, 47, "SKILL"),  # strategic planning
        (49, 65, "SKILL"),  # team coordination
        (67, 83, "SKILL"),  # budget management
        (85, 99, "SKILL"),  # risk assessment
    ]}),
    ("digital marketing social media management content creation seo optimization online advertising analytics", {"entities": [
        (0, 16, "SKILL"),  # digital marketing
        (18, 40, "SKILL"),  # social media management
        (42, 57, "SKILL"),  # content creation
        (59, 74, "SKILL"),  # seo optimization
        (76, 93, "SKILL"),  # online advertising
        (95, 103, "SKILL"),  # analytics
    ]}),
    ("data visualization statistical analysis machine learning predictive modeling data mining data interpretation", {"entities": [
        (0, 17, "SKILL"),  # data visualization
        (19, 38, "SKILL"),  # statistical analysis
        (40, 55, "SKILL"),  # machine learning
        (57, 75, "SKILL"),  # predictive modeling
        (77, 87, "SKILL"),  # data mining
        (89, 107, "SKILL"),  # Data interpretation
    ]}),
    ("software development agile methodology version control system debugging problem-solving code optimization", {"entities": [
        (0, 19, "SKILL"),  # software development
        (21, 37, "SKILL"),  # agile methodology
        (39, 60, "SKILL"),  # version control system
        (62, 72, "SKILL"),  # debugging
        (72, 86, "SKILL"),  # problem-solving
        (88, 104, "SKILL"),  # code optimization
    ]}),
    ("customer service conflict resolution empathy patience interpersonal skills time management", {"entities": [
        (0, 15, "SKILL"),  # customer service
        (17, 35, "SKILL"),  # conflict resolution
        (37, 43, "SKILL"),  # empathy
        (45, 52, "SKILL"),  # patience
        (54, 73, "SKILL"),  # interpersonal skills
        (75, 89, "SKILL"),  # time management
    ]}),
    ("cybersecurity network security penetration testing incident response threat detection encryption techniques", {"entities": [
        (0, 13, "SKILL"),  # cybersecurity
        (15, 29, "SKILL"),  # network security
        (31, 49, "SKILL"),  # penetration testing
        (51, 67, "SKILL"),  # incident response
        (69, 84, "SKILL"),  # threat detection
        (86, 106, "SKILL"),  # encryption techniques
    ]}),
    ("human resources recruitment performance appraisal employee relations HR policy development diversity and inclusion training", {"entities": [
        (0, 14, "SKILL"),  # human resources
        (16, 26, "SKILL"),  # recruitment
        (28, 48, "SKILL"),  # performance appraisal
        (50, 67, "SKILL"),  # employee relations
        (69, 89, "SKILL"),  # hr policy development
        (91, 122, "SKILL"),  # diversity and inclusion training
    ]}),
    ("public speaking presentation design audience engagement speech writing storytelling persuasion techniques", {"entities": [
        (0, 14, "SKILL"),  # public speaking
        (16, 34, "SKILL"),  # presentation design
        (36, 54, "SKILL"),  # audience engagement
        (55, 67, "SKILL"),  # speech writing
        (71, 82, "SKILL"),  # storytelling
        (84, 104, "SKILL"),  # persuasion techniques
    ]}),
    ("graphic design typography layout design color theory print production adobe creative suite", {"entities": [
        (0, 13, "SKILL"),  # graphic design
        (15, 24, "SKILL"),  # typography
        (26, 38, "SKILL"),  # layout design
        (40, 51, "SKILL"),  # color theory
        (53, 68, "SKILL"),  # print production
        (70, 89, "SKILL"),  # adobe Creative Suite
    ]}),
    ("event planning vendor management budgeting logistics coordination marketing promotion", {"entities": [
        (0, 13, "SKILL"),  # event planning
        (15, 31, "SKILL"),  # vendor management
        (33, 41, "SKILL"),  # budgeting
        (43, 64, "SKILL"),  # logistics coordination
        (66, 84, "SKILL"),  # marketing promotion
    ]}),
    ("content management system (CMS) WordPress Joomla Drupal content creation blog management SEO optimization", {"entities": [
        (0, 24, "SKILL"),  # content management system (CMS)
        (32, 40, "SKILL"),  # wordpress
        (42, 47, "SKILL"),  # joomla
        (48, 54, "SKILL"),  # drupal
        (56, 71, "SKILL"),  # content creation
        (73, 86, "SKILL"),  # blog management
        (89, 104, "SKILL"),  # seo optimization
    ]}),
    ("quality assurance testing bug tracking test case development automated testing regression testing", {"entities": [
        (0, 24, "SKILL"),  # quality assurance testing
        (26, 37, "SKILL"),  # bug tracking
        (39, 59, "SKILL"),  # test case development
        (61, 77, "SKILL"),  # automated testing
        (79, 96, "SKILL"),  # regression testing
    ]}),
    ("database administration sql database optimization data warehousing database security backup and recovery", {"entities": [
        (0, 22, "SKILL"),  # database administration
        (24, 26, "SKILL"),  # SQL
        (28, 48, "SKILL"),  # Database optimization
        (50, 65, "SKILL"),  # data warehousing
        (67, 83, "SKILL"),  # database security
        (85, 103, "SKILL"),  # backup and recovery
    ]}),
    ("business analysis requirement gathering process modeling data mapping stakeholder communication solution design", {"entities": [
        (0, 16, "SKILL"),  # business analysis
        (18, 38, "SKILL"),  # requirement gathering
        (40, 55, "SKILL"),  # process modeling
        (57, 68, "SKILL"),  # data mapping
        (70, 94, "SKILL"),  # stakeholder communication
        (96, 110, "SKILL"),  # solution design
    ]}),
    ("creative writing storytelling narrative structure character development dialogue crafting descriptive writing", {"entities": [
        (0, 15, "SKILL"),  # creative writing
        (17, 28, "SKILL"),  # storytelling
        (30, 48, "SKILL"),  # narrative structure
        (50, 60, "SKILL"),  # character development
        (72, 88, "SKILL"),  # dialogue crafting
        (90, 108, "SKILL"),  # descriptive writing
    ]}),
    ("project management team leadership Agile methodologies Scrum Kanban risk management stakeholder engagement", {"entities": [
        (0, 17, "SKILL"),  # project management
        (19, 33, "SKILL"),  # team leadership
        (35, 53, "SKILL"),  # agile methodologies
        (55, 59, "SKILL"),  # scrum
        (61, 66, "SKILL"),  # kanban
        (68, 82, "SKILL"),  # risk management
        (84, 105, "SKILL"),  # stakeholder engagement
    ]}),
    ("human resources recruitment employee relations performance appraisal hr policies compliance training and development", {"entities": [
        (0, 14, "SKILL"),  # human resources
        (16, 26, "SKILL"),  # recruitment
        (28, 45, "SKILL"),  # employee relations
        (47, 67, "SKILL"),  # performance appraisal
        (69, 79, "SKILL"),  # hr policies
        (81, 90, "SKILL"),  # compliance
        (92, 115, "SKILL"),  # training and development
    ]}),
    ("financial analysis budget management financial reporting forecasting risk assessment investment analysis", {"entities": [
        (0, 17, "SKILL"),  # financial analysis
        (19, 35, "SKILL"),  # budget management
        (37, 55, "SKILL"),  # financial reporting
        (58, 69, "SKILL"),  # forecasting
        (69, 83, "SKILL"),  # risk assessment
        (85, 103, "SKILL"),  # investment analysis
    ]}),
    ("software development object-oriented programming algorithms data structures version control system architecture debugging", {"entities": [
        (0, 19, "SKILL"),  # software development
        (21, 47, "SKILL"),  # object-oriented programming
        (49, 58, "SKILL"),  # algorithms
        (60, 74, "SKILL"),  # data structures
        (76, 90, "SKILL"),  # version control
        (92, 110, "SKILL"),  # system architecture
        (112, 120, "SKILL"),  # debugging
    ]}),
    ("customer service problem resolution interpersonal skills conflict management empathy patience", {"entities": [
        (0, 15, "SKILL"),  # customer service
        (17, 34, "SKILL"),  # problem resolution
        (36, 55, "SKILL"),  # interpersonal skills
        (57, 75, "SKILL"),  # conflict management
        (77, 83, "SKILL"),  # empathy
        (85, 92, "SKILL"),  # patience
    ]}),
    ("digital marketing seo SEM content marketing social media advertising email marketing analytics", {"entities": [
        (0, 16, "SKILL"),  # digital marketing
        (26, 42, "SKILL"),  # content marketing
        (44, 67, "SKILL"),  # social media advertising
        (69, 83, "SKILL"),  # email marketing
        (85, 93, "SKILL"),  # analytics
    ]}),
    ("network administration tcp/ip protocols network security firewall configuration vpn troubleshooting", {"entities": [
        (0, 21, "SKILL"),  # network administration
        (23, 38, "SKILL"),  # TCP/IP protocols
        (40, 55, "SKILL"),  # network security
        (57, 78, "SKILL"),  # firewall configuration
        (80, 98, "SKILL"),  # VPN
    ]}),
    ("data science machine learning deep learning natural language processing statistical analysis data visualization model deployment", {"entities": [
        (0, 11, "SKILL"),  # data science
        (13, 28, "SKILL"),  # machine learning
        (30, 42, "SKILL"),  # deep learning
        (44, 70, "SKILL"),  # natural language processing
        (72, 91, "SKILL"),  # statistical analysis
        (93, 110, "SKILL"),  # data visualization
        (112, 127, "SKILL"),  # model deployment
    ]}),
    ("content creation copywriting editing proofreading content management blogging social media management SEO", {"entities": [
        (0, 15, "SKILL"),  # content creation
        (17, 27, "SKILL"),  # copywriting
        (29, 35, "SKILL"),  # editing
        (37, 48, "SKILL"),  # proofreading
        (50, 67, "SKILL"),  # content management
        (69, 76, "SKILL"),  # blogging
        (80, 101, "SKILL"),  # social media management
        (102, 104, "SKILL"),  # seo
    ]}),
    ("web development html css javaScript front-end frameworks (e.g., React, Vue.js, Angular) back-end frameworks (e.g., Node.js, Django) api integration responsive design", {"entities": [
        (0, 14, "SKILL"),  # web development
        (16, 19, "SKILL"),  # html
        (21, 23, "SKILL"),  # CSS
        (25, 34, "SKILL"),  # JavaScript
        (36, 55, "SKILL"),  # Front-end frameworks
        (88, 106, "SKILL"),  # back-end frameworks
        (132, 146, "SKILL"),  # api integration
        (148, 164, "SKILL"),  # Responsive design
    ]}),
    ("project coordination time management multitasking organizational skills problem-solving collaboration", {"entities": [
        (0, 19, "SKILL"),  # project coordination
        (21, 35, "SKILL"),  # time management
        (37, 48, "SKILL"),  # multitasking
        (50, 70, "SKILL"),  # organizational skills
        (72, 86, "SKILL"),  # problem-solving
        (88, 100, "SKILL"),  # collaboration
    ]}),
    ("quality assurance software testing test automation bug tracking regression testing user acceptance testing", {"entities": [
        (0, 16, "SKILL"),  # quality assurance
        (18, 33, "SKILL"),  # software testing
        (35, 49, "SKILL"),  # test automation
        (51, 62, "SKILL"),  # bug tracking
        (64, 81, "SKILL"),  # regression testing
        (83, 105, "SKILL"),  # user acceptance testing
    ]}),
    ("business analysis requirement gathering data modeling process mapping stakeholder interviews gap analysis", {"entities": [
        (0, 16, "SKILL"),  # business analysis
        (18, 38, "SKILL"),  # requirement gathering
        (40, 52, "SKILL"),  # data modeling
        (54, 68, "SKILL"),  # process mapping
        (70, 91, "SKILL"),  # stakeholder interviews
        (93, 104, "SKILL"),  # gap analysis
    ]}),
    ("salesforce administration crm customization workflow automation data migration report generation", {"entities": [
        (0, 24, "SKILL"),  # salesforce administration
        (26, 42, "SKILL"),  # crm customization
        (44, 62, "SKILL"),  # workflow automation
        (64, 77, "SKILL"),  # data migration
        (79, 95, "SKILL"),  # report generation
    ]}),
    ("leadership team management strategic planning decision-making delegation conflict management", {"entities": [
        (0, 9, "SKILL"),  # Leadership
        (11, 25, "SKILL"),  # Team management
        (27, 44, "SKILL"),  # strategic planning
        (46, 60, "SKILL"),  # Decision-making
        (62, 71, "SKILL"),  # delegation
        (73, 91, "SKILL"),  # conflict management
    ]}),
    ("public speaking presentation skills audience engagement storytelling persuasion", {"entities": [
        (0, 14, "SKILL"),  # public speaking
        (16, 34, "SKILL"),  # presentation skills
        (36, 54, "SKILL"),  # audience engagement
        (56, 67, "SKILL"),  # storytelling
        (69, 78, "SKILL"),  # persuasion
    ]}),
    ("financial planning investment management retirement planning wealth management risk assessment", {"entities": [
        (0, 17, "SKILL"),  # financial planning
        (19, 39, "SKILL"),  # investment management
        (41, 59, "SKILL"),  # retirement planning
        (61, 77, "SKILL"),  # wealth management
        (79, 93, "SKILL"),  # risk assessment
    ]}),
    ("agile methodology sprint planning scrum ceremonies backlog grooming agile coaching", {"entities": [
        (0, 16, "SKILL"),  # agile methodology
        (18, 32, "SKILL"),  # sprint planning
        (34, 49, "SKILL"),  # scrum ceremonies
        (51, 66, "SKILL"),  # backlog grooming
        (68, 81, "SKILL"),  # agile coaching
    ]}),
    ("ui/ux design wireframing prototyping user research usability testing user interface design user experience optimization", {"entities": [
        (0, 11, "SKILL"),  # UI/UX design
        (13, 23, "SKILL"),  # wireframing
        (25, 36, "SKILL"),  # prototyping
        (37, 49, "SKILL"),  # user research
        (51, 67, "SKILL"),  # usability testing
        (69, 89, "SKILL"),  # user interface design
        (91, 118, "SKILL"),  # user experience optimization
    ]}),
    ("data entry data processing attention to detail time management organization skills", {"entities": [
        (0, 9, "SKILL"),    # data entry
        (11, 25, "SKILL"),  # data processing
        (27, 45, "SKILL"),  # attention to detail
        (47, 61, "SKILL"),  # time management
        (63, 81, "SKILL"),  # organization skills
    ]}),
    ("network administration system configuration troubleshooting it security network monitoring", {"entities": [
        (0, 21, "SKILL"),  # network administration
        (23, 42, "SKILL"),  # system configuration
        (44, 58, "SKILL"),  # troubleshooting
        (60, 70, "SKILL"),  # it security
        (72, 89, "SKILL"),  # network monitoring
    ]}),
    ("graphic design typography layout design color theory image editing digital illustration", {"entities": [
        (0, 13, "SKILL"),   # graphic design
        (15, 24, "SKILL"),  # typography
        (26, 38, "SKILL"),  # layout design
        (40, 51, "SKILL"),  # color theory
        (53, 65, "SKILL"),  # image editing
        (67, 86, "SKILL"),  # digital illustration
    ]}),
    ("project management risk assessment resource allocation stakeholder communication progress tracking", {"entities": [
        (0, 17, "SKILL"),   # project management
        (19, 33, "SKILL"),  # risk assessment
        (35, 53, "SKILL"),  # resource allocation
        (55, 79, "SKILL"),  # stakeholder communication
        (81, 97, "SKILL"),  # progress tracking
    ]}),
    ("content writing copywriting seo optimization content editing proofreading content marketing", {"entities": [
        (0, 14, "SKILL"),   # content writing
        (16, 26, "SKILL"),  # copywriting
        (28, 43, "SKILL"),  # SEO optimization
        (45, 59, "SKILL"),  # content editing
        (61, 72, "SKILL"),  # proofreading
        (74, 90, "SKILL"),  # content marketing
    ]}),
    ("mechanical engineering CAD modeling stress analysis material science thermodynamics fluid mechanics", {"entities": [
        (0, 20, "SKILL"),   # mechanical engineering
        (23, 34, "SKILL"),  # cad modeling
        (36, 50, "SKILL"),  # stress analysis
        (52, 67, "SKILL"),  # material science
        (69, 82, "SKILL"),  # thermodynamics
        (84, 98, "SKILL"),  # fluid mechanics
    ]}),
    ("customer service problem resolution conflict management empathy patience communication skills", {"entities": [
        (0, 15, "SKILL"),   # customer service
        (17, 34, "SKILL"),  # problem resolution
        (36, 54, "SKILL"),  # conflict management
        (56, 62, "SKILL"),  # empathy
        (64, 71, "SKILL"),  # patience
        (73, 92, "SKILL"),  # communication skills
    ]}),
    ("digital marketing social media management content creation audience engagement analytics reporting", {"entities": [
        (0, 16, "SKILL"),   # digital marketing
        (18, 40, "SKILL"),  # social media management
        (42, 57, "SKILL"),  # content creation
        (59, 77, "SKILL"),  # audience engagement
        (79, 97, "SKILL"),  # analytics reporting
    ]}),
    ("software development coding debugging problem-solving algorithms data structures version control", {"entities": [
        (0, 19, "SKILL"),   # software development
        (21, 26, "SKILL"),  # coding
        (28, 36, "SKILL"),  # debugging
        (38, 52, "SKILL"),  # problem-solving
        (54, 63, "SKILL"),  # algorithms
        (665, 79, "SKILL"),  # data structures
        (81, 95, "SKILL"),  # version control
    ]}),
    ("event planning logistics coordination vendor management budget management negotiation skills", {"entities": [
        (0, 14, "SKILL"),   # event planning
        (15, 36, "SKILL"),  # logistics coordination
        (38, 54, "SKILL"),  # vendor management
        (56, 72, "SKILL"),  # budget management
        (74, 91, "SKILL"),  # negotiation skills
    ]}),
    ("public speaking presentation delivery audience engagement storytelling persuasion", {"entities": [
        (0, 14, "SKILL"),   # public speaking
        (16, 36, "SKILL"),  # presentation delivery
        (38, 56, "SKILL"),  # Audience engagement
        (58, 69, "SKILL"),  # storytelling
        (71, 80, "SKILL"),  # persuasion
    ]}),
    ("data analysis statistical modeling data visualization machine learning algorithms predictive analytics", {"entities": [
        (0, 12, "SKILL"),   # data analysis
        (14, 33, "SKILL"),  # statistical modeling
        (35, 52, "SKILL"),  # data visualization
        (54, 80, "SKILL"),  # machine learning algorithms
        (82, 101, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership agile methodologies stakeholder communication risk mitigation", {"entities": [
        (0, 17, "SKILL"),   #project management
        (19, 33, "SKILL"),  # team leadership
        (35, 53, "SKILL"),  # agile methodologies
        (55, 79, "SKILL"),  # stakeholder communication
        (81, 95, "SKILL"),  # risk mitigation
    ]}),
    ("financial planning investment management portfolio analysis retirement planning wealth management", {"entities": [
        (0, 17, "SKILL"),   # financial planning
        (19, 39, "SKILL"),  # investment management
        (41, 58, "SKILL"),  # portfolio analysis
        (60, 78, "SKILL"),  # retirement planning
        (80, 96, "SKILL"),  # wealth management
    ]}),
    ("customer relationship management crm software sales pipeline management lead generation customer retention strategies", {"entities": [
        (0, 31, "SKILL"),   # customer relationship management
        (33, 44, "SKILL"),  # crm software
        (46, 70, "SKILL"),  # sales pipeline management
        (72, 86, "SKILL"),  # lead generation
        (88, 116, "SKILL"), # customer retention strategies
    ]}),
    ("legal research writing legal documents case preparation court representation negotiation advocacy", {"entities": [
        (0, 13, "SKILL"),   # legal research
        (15, 37, "SKILL"),  # writing legal documents
        (39, 54, "SKILL"),  # case preparation
        (56, 75, "SKILL"),  # court representation
        (77, 87, "SKILL"),  # negotiation
        (89, 96, "SKILL"),  # advocacy
    ]}),
    ("database administration sql queries database optimization backup and recovery data integrity security measures", {"entities": [
        (0, 22, "SKILL"),   # database administration
        (24, 34, "SKILL"),  # SQL queries
        (36, 56, "SKILL"),  # database optimization
        (58, 76, "SKILL"),  # backup and recovery
        (78, 91, "SKILL"),  # data integrity
        (93, 109, "SKILL"), # security measures
    ]}),
    ("network administration system configuration network troubleshooting cybersecurity protocols firewall management", {"entities": [
        (0, 21, "SKILL"),   # network administration
        (23, 42, "SKILL"),  # system configuration
        (44, 66, "SKILL"),  # network troubleshooting
        (69, 90, "SKILL"),  # cybersecurity protocols
        (92, 110, "SKILL"), # firewall management
    ]}),
    ("graphic design Adobe Creative Suite typography color theory layout design branding", {"entities": [
        (0, 13, "SKILL"),   # graphic design
        (15, 34, "SKILL"),  # adobe creative suite
        (36, 45, "SKILL"),  # typography
        (47, 58, "SKILL"),  # color theory
        (60, 72, "SKILL"),  # layout design
        (74, 81, "SKILL"),  # branding
    ]}),
    ("event planning budget management vendor negotiation venue selection event promotion logistics coordination", {"entities": [
        (0, 13, "SKILL"),   # event planning
        (15, 31, "SKILL"),  # budget management
        (33, 50, "SKILL"),  # vendor negotiation
        (52, 67, "SKILL"),  # venue selection
        (69, 82, "SKILL"),  # event promotion
        (84, 105, "SKILL"), # logistics coordination
    ]}),
    ("content creation content strategy social media management seo optimization content distribution analytics", {"entities": [
        (0, 15, "SKILL"),   # content creation
        (17, 32, "SKILL"),  # content strategy
        (34, 56, "SKILL"),  # social media management
        (56, 71, "SKILL"),  # seo optimization
        (73, 91, "SKILL"),  # Content distribution
        (93, 103, "SKILL"), # Analytics
    ]}),
    ("quality assurance software testing bug tracking test case development automated testing regression testing", {"entities": [
        (0, 16, "SKILL"),   # quality assurance
        (18, 33, "SKILL"),  # software testing
        (34, 46, "SKILL"),  # bug tracking
        (48, 68, "SKILL"),  # test case development
        (70, 86, "SKILL"),  # automated testing
        (88, 105, "SKILL"), # regression testing
    ]}),
    ("project management stakeholder communication risk assessment project scheduling budget allocation team leadership", {"entities": [
        (0, 17, "SKILL"),   # project management
        (19, 43, "SKILL"),  # stakeholder communication
        (45, 59, "SKILL"),  # risk assessment
        (61, 78, "SKILL"),  # project scheduling
        (80, 96, "SKILL"),  # budget allocation
        (98, 112, "SKILL"), # team leadership
    ]}),
    ("customer service complaint resolution client retention customer satisfaction product knowledge empathy", {"entities": [
        (0, 15, "SKILL"),   # customer service
        (17, 36, "SKILL"),  # complaint resolution
        (38, 53, "SKILL"),  # client retention
        (55, 75, "SKILL"),  # customer satisfaction
        (77, 93, "SKILL"),  # product knowledge
        (95, 101, "SKILL"),  # empathy
    ]}),
    ("web development HTML CSS JavaScript responsive design web accessibility cross-browser compatibility", {"entities": [
        (0, 14, "SKILL"),   # web development
        (16, 19, "SKILL"),  # html
        (21, 23, "SKILL"),  # CSS
        (25, 34, "SKILL"),  # javaScript
        (36, 52, "SKILL"),  # responsive design
        (54, 70, "SKILL"),  # web accessibility
        (72, 98, "SKILL"),  # cross-browser compatibility
    ]}),
    ("legal research writing legal briefs contract negotiation litigation support legal analysis", {"entities": [
        (0, 21, "SKILL"),   # legal research
        (23, 34, "SKILL"),  # legal briefs
        (36, 55, "SKILL"),  # contract negotiation
        (57, 74, "SKILL"),  # litigation support
        (76, 89, "SKILL"),  # legal analysis
    ]}),
    ("data entry data cleaning data analysis data visualization database management spreadsheet proficiency", {"entities": [
        (0, 9, "SKILL"),     # Data entry
        (11, 23, "SKILL"),   # data cleaning
        (25, 37, "SKILL"),   # data analysis
        (39, 56, "SKILL"),   # data visualization
        (58, 76, "SKILL"),   # database management
        (78, 100, "SKILL"),   # spreadsheet proficiency
    ]}),
    ("public speaking presentation design audience engagement storytelling persuasion", {"entities": [
        (0, 14, "SKILL"),   # public speaking
        (16, 34, "SKILL"),  # presentation design
        (35, 53, "SKILL"),  # audience engagement
        (55, 66, "SKILL"),  # storytelling
        (69, 78, "SKILL"),  # persuasion
    ]}),
    ("network administration cybersecurity threat detection incident response firewall configuration VPN management", {"entities": [
        (0, 21, "SKILL"),   # Network administration
        (23, 35, "SKILL"),  # cybersecurity
        (37, 52, "SKILL"),  # Threat detection
        (54, 70, "SKILL"),  # Incident response
        (72, 93, "SKILL"),  # Firewall configuration
        (95, 108, "SKILL"), # VPN management
    ]}),
    ("graphic design Adobe Photoshop Illustrator InDesign typography color theory layout design", {"entities": [
        (0, 13, "SKILL"),   # graphic design
        (15, 29, "SKILL"),  # adobe Photosho
        (43, 59, "SKILL"),  # Typography
        (61, 72, "SKILL"),  # Color theory
        (74, 86, "SKILL"),  # Layout design
    ]}),
    ("human resources recruitment employee onboarding performance appraisal HR policies conflict resolution", {"entities": [
        (0, 14, "SKILL"),   # human resources
        (16, 26, "SKILL"),  # recruitment
        (28, 46, "SKILL"),  # employee onboarding
        (48, 68, "SKILL"),  # performance appraisal
        (70, 80, "SKILL"),  # hr policies
        (82, 100, "SKILL"), # conflict resolution
    ]}),
    ("event planning venue selection vendor coordination budget management logistics execution event marketing", {"entities": [
        (0, 13, "SKILL"),   # event planning
        (15, 29, "SKILL"),  # venue selection
        (31, 49, "SKILL"),  # vendor coordination
        (51, 67, "SKILL"),  # budget management
        (69, 87, "SKILL"),  # logistics execution
        (89, 103, "SKILL"),  # event marketing
    ]}),
    ("medical coding billing insurance claims processing healthcare terminology HIPAA compliance patient confidentiality", {"entities": [
        (0, 13, "SKILL"),   # Medical coding
        (15, 21, "SKILL"),  # billing
        (23, 49, "SKILL"),  # insurance claims processing
        (51, 72, "SKILL"),  # healthcare terminology
        (74, 89, "SKILL"),  # HIPAA compliance
        (91, 113, "SKILL"), # patient confidentiality
    ]}),
    ("data analysis statistical modeling data visualization machine learning algorithms predictive analytics", {"entities": [
    (0, 12, "SKILL"),  # data analysis
    (14, 33, "SKILL"),  # statistical modeling
    (35, 52, "SKILL"),  # data visualization
    (54, 80, "SKILL"),  # machine learning algorithms
    (82, 101, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership agile methodologies stakeholder communication risk mitigation", {"entities": [
    (0, 17, "SKILL"),  # project management
    (19, 33, "SKILL"),  # team leadership
    (35, 53, "SKILL"),  # agile methodologies
    (55, 79, "SKILL"),  # stakeholder communication
    (81, 95, "SKILL"),  # risk mitigation
    ]}),
    ("financial planning investment management portfolio analysis retirement planning wealth management", {"entities": [
    (0, 17, "SKILL"),  # financial planning
    (19, 39, "SKILL"),  # investment management
    (41, 58, "SKILL"),  # portfolio analysis
    (60, 78, "SKILL"),  # retirement planning
    (80, 96, "SKILL"),  # wealth management
    ]}),
    ("customer relationship management crm software sales pipeline management lead generation customer retention strategies", {"entities": [
    (0, 31, "SKILL"),  # customer relationship management
    (33, 44, "SKILL"),  # CRM software
    (46, 70, "SKILL"),  # sales pipeline management
    (72, 86, "SKILL"),  # lead generation
    (88, 116, "SKILL"),  # customer retention strategies
    ]}),
    ("software engineering software development coding debugging problem-solving", {"entities": [
    (0, 19, "SKILL"),  # software engineering
    (21, 40, "SKILL"),  # software development
    (42, 47, "SKILL"),  # coding
    (49, 57, "SKILL"),  # debugging
    (59, 73, "SKILL"),  # problem-solving
    ]}),
    ("data analysis data visualization statistical modeling machine learning predictive analytics", {"entities": [
    (0, 12, "SKILL"),  # data analysis
    (14, 31, "SKILL"),  # data visualization
    (33, 51, "SKILL"),  # statistical modeling
    (54, 69, "SKILL"),  # machine learning
    (71, 90, "SKILL"),  # predictive analytics
    ]}),
    ("project management team leadership stakeholder communication risk assessment agile methodology", {"entities": [
    (0, 17, "SKILL"),  # project management
    (19, 33, "SKILL"),  # team leadership
    (35, 59, "SKILL"),  # stakeholder communication
    (61, 75, "SKILL"),  # risk assessment
    (77, 93, "SKILL"),  # agile methodology
    ]}),
    ("customer service communication problem resolution conflict management empathy", {"entities": [
        (0, 15, "SKILL"),  # customer service
        (17, 29, "SKILL"),  # communication
        (31, 48, "SKILL"),  # problem resolution
        (50, 68, "SKILL"),  # conflict management
        (70, 76, "SKILL"), # empathy
    ]}),
    ("web development responsive design front-end frameworks back-end development API integration", {"entities": [
    (0, 14, "SKILL"),  # web development
    (16, 32, "SKILL"),  # responsive design
    (34, 53, "SKILL"),  # front-end frameworks
    (55, 74, "SKILL"),  # back-end development
    (76, 90, "SKILL"),  # API integration
    ]}),
    ("sales negotiation client acquisition market research lead generation CRM management", {"entities": [
    (0, 16, "SKILL"),    # sales
    (18, 35, "SKILL"),  # client acquisition
    (37, 51, "SKILL"),  # market research
    (53, 67, "SKILL"),  # lead generation
    (69, 82, "SKILL"),  # crm management
    ]}),


]

transformed_training_data = [
    (text.lower(), annotation)  # Convert text to lowercase
    for text, annotation in training_data
]

# Convert training data to Example objects
examples = []
for text, annotations in training_data:
    doc = nlp.make_doc(text)
    example = Example.from_dict(doc, annotations)
    examples.append(example)

# Train the model
nlp.begin_training()
for _ in range(25):  # Adjust the number of iterations as needed
    for example in examples:
        nlp.update([example], drop=0.5)  # Adjust dropout rate as needed


# Save the trained model
nlp.to_disk("custom_ner_model")


nlp = spacy.load("custom_ner_model")

# Sample text to test the model
text = "sales negotiation client acquisition market research lead generation CRM management"
text_lowercase = text.lower()

# Process the text
doc = nlp(text_lowercase)

# Access named entities
skills = [ent.text for ent 
          in doc.ents if ent.label_ == "SKILL"]

# Print identified skills
print("Identified Skills:")
for skill in skills:
    print("-", skill)
# Out:
# Identified Skills:
# - sales negotiation
# - client acquisition
# - lead generation

# %%
display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# 0                douglas          isle of man     ['intern']         26801
# 1               ashgabat         turkmenistan     ['intern']        100340
# 2                  macao      macao sar china  ['temporary']         84525
# 3              portonovo                benin   ['fulltime']        129896
# 4               santiago                chile     ['intern']         53944
# ...                  ...                  ...            ...           ...
# 107359  city of victoria  hong kong sar china   ['parttime']         65917
# 107360            ottawa               canada     ['intern']         75174
# 107361         islamabad             pakistan     ['intern']        120357
# 107362        montevideo              uruguay   ['fulltime']         84553
# 107363         ngerulmud                palau  ['temporary']         13014
#
#        Job Posting Date  Preference      Contact Person  \
# 0            2022-04-24  ['female']  brandon cunningham
# 1            2022-12-19  ['female']    francisco larsen
# 2            2022-09-14    ['male']         gary gibson
# 3            2023-02-25  ['female']          joy lucero
# 4            2022-10-11  ['female']       julie johnson
# ...                 ...         ...                 ...
# 107359       2021-11-02  ['female']        steven meyer
# 107360       2023-07-01    ['both']      daniel lambert
# 107361       2023-05-18  ['female']      gregory garcia
# 107362       2023-04-18    ['both']       matthew bruce
# 107363       2022-07-07  ['female']    kenneth gonzales
#
#                                Job Title  \
# 0       ['digital marketing specialist']
# 1                      ['web developer']
# 2                 ['operations manager']
# 3                   ['network engineer']
# 4                      ['event manager']
# ...                                  ...
# 107359             ['chemical engineer']
# 107360                 ['uxui designer']
# 107361              ['account director']
# 107362            ['nurse practitioner']
# 107363                    ['qa analyst']
#
#                                             Role      Job Portal  \
# 0                       ['social media manager']        snagajob
# 1                     ['frontend web developer']        idealist
# 2                    ['quality control manager']    jobs2careers
# 3                  ['wireless network engineer']        flexjobs
# 4                         ['conference manager']    jobs2careers
# ...                                          ...             ...
# 107359  ['research and development rd engineer']          indeed
# 107360               ['user interface designer']          indeed
# 107361                    ['account strategist']        snagajob
# 107362         ['acute care nurse practitioner']        flexjobs
# 107363              ['automation test engineer']  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                      Company  \
# 0                      ['icahn enterprises']
# 1           ['pnc financial services group']
# 2        ['united services automobile assn']
# 3                                   ['hess']
# 4                           ['cairn energy']
# ...                                      ...
# 107359       ['the goldman sachs group inc']
# 107360  ['thrivent financial for lutherans']
# 107361                      ['downer group']
# 107362                ['oreilly automotive']
# 107363               ['world fuel services']
#
#                                           Company Profile
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
# [107364 rows x 20 columns]

# %%
# Load the trained NER model
nlp = spacy.load("custom_ner_model")

# Sample dataset with a "skills" column
dataset = working.to_dict(orient="records")

# Define the column name containing the text to analyze
text_column = "skills"

# Process each row of text and extract skills
for row in dataset:
    # Get the text from the specified column
    text = row[text_column]
    
    # Process the text with the NER model
    doc = nlp(text.lower())  # Convert text to lowercase for consistency
    
    # Extract identified skills
    identified_skills = [ent.text for ent in doc.ents if ent.label_ == "SKILL"]
    
    # Update the dataset with the identified skills
    row["tokenized_skills"] = identified_skills

# Convert the dataset back to a DataFrame
working = pd.DataFrame(dataset)

# Display the DataFrame with the new column
display(working)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years      ['mtech']       59-99k
# 1        398454096642776  2 to 12 years        ['bca']      56-116k
# 2        481640072963533  0 to 12 years        ['phd']      61-104k
# 3        688192671473044  4 to 11 years        ['phd']       65-91k
# 4        117057806156508  1 to 12 years        ['mba']       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years        ['bba']      60-128k
# 107360   669857235415970  2 to 15 years        ['mba']      59-121k
# 107361  2722200185343244  0 to 11 years        ['mca']       59-80k
# 107362  2740245700222760   1 to 9 years        ['bba']       63-83k
# 107363  2728583024325919  0 to 13 years        ['bca']       59-98k
#
#                 location              Country      Work Type  Company Size  \
# 0                douglas          isle of man     ['intern']         26801
# 1               ashgabat         turkmenistan     ['intern']        100340
# 2                  macao      macao sar china  ['temporary']         84525
# 3              portonovo                benin   ['fulltime']        129896
# 4               santiago                chile     ['intern']         53944
# ...                  ...                  ...            ...           ...
# 107359  city of victoria  hong kong sar china   ['parttime']         65917
# 107360            ottawa               canada     ['intern']         75174
# 107361         islamabad             pakistan     ['intern']        120357
# 107362        montevideo              uruguay   ['fulltime']         84553
# 107363         ngerulmud                palau  ['temporary']         13014
#
#        Job Posting Date  Preference  ...                         Job Title  \
# 0            2022-04-24  ['female']  ...  ['digital marketing specialist']
# 1            2022-12-19  ['female']  ...                 ['web developer']
# 2            2022-09-14    ['male']  ...            ['operations manager']
# 3            2023-02-25  ['female']  ...              ['network engineer']
# 4            2022-10-11  ['female']  ...                 ['event manager']
# ...                 ...         ...  ...                               ...
# 107359       2021-11-02  ['female']  ...             ['chemical engineer']
# 107360       2023-07-01    ['both']  ...                 ['uxui designer']
# 107361       2023-05-18  ['female']  ...              ['account director']
# 107362       2023-04-18    ['both']  ...            ['nurse practitioner']
# 107363       2022-07-07  ['female']  ...                    ['qa analyst']
#
#                                             Role      Job Portal  \
# 0                       ['social media manager']        snagajob
# 1                     ['frontend web developer']        idealist
# 2                    ['quality control manager']    jobs2careers
# 3                  ['wireless network engineer']        flexjobs
# 4                         ['conference manager']    jobs2careers
# ...                                          ...             ...
# 107359  ['research and development rd engineer']          indeed
# 107360               ['user interface designer']          indeed
# 107361                    ['account strategist']        snagajob
# 107362         ['acute care nurse practitioner']        flexjobs
# 107363              ['automation test engineer']  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                      Company  \
# 0                      ['icahn enterprises']
# 1           ['pnc financial services group']
# 2        ['united services automobile assn']
# 3                                   ['hess']
# 4                           ['cairn energy']
# ...                                      ...
# 107359       ['the goldman sachs group inc']
# 107360  ['thrivent financial for lutherans']
# 107361                      ['downer group']
# 107362                ['oreilly automotive']
# 107363               ['world fuel services']
#
#                                           Company Profile  \
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
#                                          tokenized_skills
# 0                            [community, engagement paid]
# 1       [html css, javascript, frontend frameworks, ex...
# 2       [quality, control processes, methodologies, st...
# 3       [wireless network, design and, security protoc...
# 4                  [event planning, conference logistics]
# ...                                                   ...
# 107359  [research and, with crossfunctional, expertise...
# 107360                                                 []
# 107361                                                 []
# 107362                [emergency medicine, critical care]
# 107363                                                 []
#
# [107364 rows x 21 columns]

# %%
df.to_csv('skill_token.csv', index=False)

# %%
import spacy

# Load the trained NER model
nlp = spacy.load("custom_ner_model")

# Sample dataset with a "skills" column
dataset = df.to_dict(orient="records")

# Define the column name containing the text to analyze
text_column = "skills"

# Process each row of text and extract skills
for row in dataset:
    # Get the text from the specified column
    text = row[text_column]
    
    # Process the text with the NER model
    doc = nlp(text.lower())  # Convert text to lowercase for consistency
    
    # Extract identified skills
    identified_skills = [ent.text for ent in doc.ents if ent.label_ == "SKILL"]
    
    # Update the dataset with the identified skills
    row["identified_skills"] = identified_skills
    
    # Tokenize the identified skills
    skill_tokens = []
    for token in doc:
        if token.text in identified_skills:
            skill_tokens.append(token.text)
    
    # Update the dataset with the tokenized skills
    row["skills"] = row["skills"].join(skill_tokens)

# Create a new DataFrame with the results
result_df = pd.DataFrame(dataset)

# Display the results
display(df)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years          mtech       59-99k
# 1        398454096642776  2 to 12 years            bca      56-116k
# 2        481640072963533  0 to 12 years            phd      61-104k
# 3        688192671473044  4 to 11 years            phd       65-91k
# 4        117057806156508  1 to 12 years            mba       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years            bba      60-128k
# 107360   669857235415970  2 to 15 years            mba      59-121k
# 107361  2722200185343244  0 to 11 years            mca       59-80k
# 107362  2740245700222760   1 to 9 years            bba       63-83k
# 107363  2728583024325919  0 to 13 years            bca       59-98k
#
#                 location              Country  Work Type  Company Size  \
# 0                douglas          isle of man     intern         26801
# 1               ashgabat         turkmenistan     intern        100340
# 2                  macao      macao sar china  temporary         84525
# 3              portonovo                benin   fulltime        129896
# 4               santiago                chile     intern         53944
# ...                  ...                  ...        ...           ...
# 107359  city of victoria  hong kong sar china   parttime         65917
# 107360            ottawa               canada     intern         75174
# 107361         islamabad             pakistan     intern        120357
# 107362        montevideo              uruguay   fulltime         84553
# 107363         ngerulmud                palau  temporary         13014
#
#        Job Posting Date Preference  ...                     Job Title  \
# 0            2022-04-24     female  ...  digital marketing specialist
# 1            2022-12-19     female  ...                 web developer
# 2            2022-09-14       male  ...            operations manager
# 3            2023-02-25     female  ...              network engineer
# 4            2022-10-11     female  ...                 event manager
# ...                 ...        ...  ...                           ...
# 107359       2021-11-02     female  ...             chemical engineer
# 107360       2023-07-01       both  ...                 uxui designer
# 107361       2023-05-18     female  ...              account director
# 107362       2023-04-18       both  ...            nurse practitioner
# 107363       2022-07-07     female  ...                    qa analyst
#
#                                         Role      Job Portal  \
# 0                       social media manager        snagajob
# 1                     frontend web developer        idealist
# 2                    quality control manager    jobs2careers
# 3                  wireless network engineer        flexjobs
# 4                         conference manager    jobs2careers
# ...                                      ...             ...
# 107359  research and development rd engineer          indeed
# 107360               user interface designer          indeed
# 107361                    account strategist        snagajob
# 107362         acute care nurse practitioner        flexjobs
# 107363              automation test engineer  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                  Company  \
# 0                      icahn enterprises
# 1           pnc financial services group
# 2        united services automobile assn
# 3                                   hess
# 4                           cairn energy
# ...                                  ...
# 107359       the goldman sachs group inc
# 107360  thrivent financial for lutherans
# 107361                      downer group
# 107362                oreilly automotive
# 107363               world fuel services
#
#                                           Company Profile  \
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
#                                          tokenized_skills
# 0       [social media, eg facebook, twitter instagram,...
# 1       [html, css, javascript, frontend frameworks, e...
# 2       [quality control, processes, and methodologies...
# 3       [architecture wifi standards, rf, radio, frequ...
# 4       [event planning, conference, logistics, budget...
# ...                                                   ...
# 107359  [processes, product, experimentation, data ana...
# 107360  [ui design, principles, best, practices, graph...
# 107361  [account management, client, relations, market...
# 107362  [acute care, nursing, emergency, critical care...
# 107363  [test automation, test, framework development,...
#
# [107364 rows x 21 columns]

# %%
import pandas as pd 

skill = pd.read_csv('skill_token.csv')
display(skill)
# Out:
#                   Job Id     Experience Qualifications Salary Range  \
# 0       1089843540111562  5 to 15 years          mtech       59-99k
# 1        398454096642776  2 to 12 years            bca      56-116k
# 2        481640072963533  0 to 12 years            phd      61-104k
# 3        688192671473044  4 to 11 years            phd       65-91k
# 4        117057806156508  1 to 12 years            mba       64-87k
# ...                  ...            ...            ...          ...
# 107359  1983179143713411  3 to 12 years            bba      60-128k
# 107360   669857235415970  2 to 15 years            mba      59-121k
# 107361  2722200185343244  0 to 11 years            mca       59-80k
# 107362  2740245700222760   1 to 9 years            bba       63-83k
# 107363  2728583024325919  0 to 13 years            bca       59-98k
#
#                 location              Country  Work Type  Company Size  \
# 0                douglas          isle of man     intern         26801
# 1               ashgabat         turkmenistan     intern        100340
# 2                  macao      macao sar china  temporary         84525
# 3              portonovo                benin   fulltime        129896
# 4               santiago                chile     intern         53944
# ...                  ...                  ...        ...           ...
# 107359  city of victoria  hong kong sar china   parttime         65917
# 107360            ottawa               canada     intern         75174
# 107361         islamabad             pakistan     intern        120357
# 107362        montevideo              uruguay   fulltime         84553
# 107363         ngerulmud                palau  temporary         13014
#
#        Job Posting Date Preference  ...                     Job Title  \
# 0            2022-04-24     female  ...  digital marketing specialist
# 1            2022-12-19     female  ...                 web developer
# 2            2022-09-14       male  ...            operations manager
# 3            2023-02-25     female  ...              network engineer
# 4            2022-10-11     female  ...                 event manager
# ...                 ...        ...  ...                           ...
# 107359       2021-11-02     female  ...             chemical engineer
# 107360       2023-07-01       both  ...                 uxui designer
# 107361       2023-05-18     female  ...              account director
# 107362       2023-04-18       both  ...            nurse practitioner
# 107363       2022-07-07     female  ...                    qa analyst
#
#                                         Role      Job Portal  \
# 0                       social media manager        snagajob
# 1                     frontend web developer        idealist
# 2                    quality control manager    jobs2careers
# 3                  wireless network engineer        flexjobs
# 4                         conference manager    jobs2careers
# ...                                      ...             ...
# 107359  research and development rd engineer          indeed
# 107360               user interface designer          indeed
# 107361                    account strategist        snagajob
# 107362         acute care nurse practitioner        flexjobs
# 107363              automation test engineer  internshipscom
#
#                                           Job Description  \
# 0       social media managers oversee an organizations...
# 1       frontend web developers design and implement u...
# 2       quality control managers establish and enforce...
# 3       wireless network engineers design implement an...
# 4       a conference manager coordinates and manages c...
# ...                                                   ...
# 107359  conduct research design experiments and develo...
# 107360  user interface designers focus on the visual a...
# 107361  account strategists work in advertising or mar...
# 107362  acute care nurse practitioners focus on managi...
# 107363  automation test engineers develop automated te...
#
#                                                  Benefits  \
# 0       flexible spending accounts fsas relocation ass...
# 1       health insurance retirement plans paid time of...
# 2       legal assistance bonuses and incentive program...
# 3       transportation benefits professional developme...
# 4       flexible spending accounts fsas relocation ass...
# ...                                                   ...
# 107359  health insurance retirement plans flexible wor...
# 107360  employee assistance programs eap tuition reimb...
# 107361  life and disability insurance stock options or...
# 107362  tuition reimbursement stock options or equity ...
# 107363  employee assistance programs eap tuition reimb...
#
#                                                    skills  \
# 0       social media platforms eg facebook twitter ins...
# 1       html css javascript frontend frameworks eg rea...
# 2       quality control processes and methodologies st...
# 3       wireless network design and architecture wifi ...
# 4       event planning conference logistics budget man...
# ...                                                   ...
# 107359  research and development processes product inn...
# 107360  ui design principles and best practices graphi...
# 107361  account management client relations marketing ...
# 107362  acute care nursing emergency medicine critical...
# 107363  test automation test framework development con...
#
#                                          Responsibilities  \
# 0       manage and grow social media accounts create e...
# 1       design and code user interfaces for websites e...
# 2       establish and enforce quality control standard...
# 3       design configure and optimize wireless network...
# 4       specialize in conference and convention planni...
# ...                                                   ...
# 107359  work on research and development of new produc...
# 107360  create visually appealing user interfaces ui t...
# 107361  develop account strategies and marketing plans...
# 107362  specialize in acute care settings managing com...
# 107363  develop and maintain automated test scripts us...
#
#                                  Company  \
# 0                      icahn enterprises
# 1           pnc financial services group
# 2        united services automobile assn
# 3                                   hess
# 4                           cairn energy
# ...                                  ...
# 107359       the goldman sachs group inc
# 107360  thrivent financial for lutherans
# 107361                      downer group
# 107362                oreilly automotive
# 107363               world fuel services
#
#                                           Company Profile  \
# 0       sector diversified industry diversified financ...
# 1       sector financial services industry commercial ...
# 2       sector insurance industry insurance property a...
# 3       sector energy industry mining crudeoil product...
# 4       sector energy industry energy  oil  gas explor...
# ...                                                   ...
# 107359  sector financial servicesinvestment banking in...
# 107360  sector financial services industry insurance l...
# 107361  sector constructioninfrastructure industry con...
# 107362  sector automotive industry specialty retailers...
# 107363  sector energy industry energycitymiamistateflo...
#
#                                          tokenized_skills
# 0       ['social media', 'eg facebook', 'twitter insta...
# 1       ['html', 'css', 'javascript', 'frontend framew...
# 2       ['quality control', 'processes', 'and methodol...
# 3       ['architecture wifi standards', 'rf', 'radio',...
# 4       ['event planning', 'conference', 'logistics', ...
# ...                                                   ...
# 107359  ['processes', 'product', 'experimentation', 'd...
# 107360  ['ui design', 'principles', 'best', 'practices...
# 107361  ['account management', 'client', 'relations', ...
# 107362  ['acute care', 'nursing', 'emergency', 'critic...
# 107363  ['test automation', 'test', 'framework develop...
#
# [107364 rows x 21 columns]
